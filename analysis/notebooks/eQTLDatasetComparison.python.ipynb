# %% [markdown]
# # Compare uncorrected, Bonferroni-corrected, and Metasoft eQTL datasets

# %% [markdown]
# ## Housekeeping

# %% [markdown]
# ### Background
#
# * Want to compare the effect of using Bonferroni-correction on number of tissues affected per eQTL and see how this also compares to Metasoft multi-tissue method

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+mysqlconnector://jupyter:password@localhost:3306/gtex', echo=False)

# %% [markdown]
# ### Functions

# %%
import re
def removeGeneIDVersions(text):
    return re.findall('(ENSG\d+)', text)[0]

# %% [markdown]
# ---

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Export list of SNP/gene pairs with number of tissues affected

# %% [markdown]
# #### GTEx per tissue data without Bonferroni-correction

# %%
eQTLsAndNumTissuesAffectedUncorrected = pd.read_sql_query(
    'SELECT variant_id, gene_id, count(*) AS `count` FROM `v7` GROUP BY variant_id, gene_id',
    engine,
    coerce_float=True
)
eQTLsAndNumTissuesAffectedUncorrected['gene_id'] = eQTLsAndNumTissuesAffectedUncorrected['gene_id'].apply(removeGeneIDVersions)

# %%
eQTLsAndNumTissuesAffectedUncorrected.describe()
# Out:
#               count
# count  7.627598e+06
# mean   4.822141e+00
# std    7.782665e+00
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    2.000000e+00
# 75%    4.000000e+00
# max    4.800000e+01

# %% [markdown]
# #### Bonferroni-corrected

# %%
eQTLsAndNumTissuesAffectedBonferroni = pd.read_sql_query(
    'SELECT variant_id, gene_id, count(*) AS `count` FROM `v7` WHERE sigAfterBonferroni = 1 GROUP BY variant_id, gene_id',
    engine,
    coerce_float=True
)
eQTLsAndNumTissuesAffectedBonferroni['gene_id'] = eQTLsAndNumTissuesAffectedBonferroni['gene_id'].apply(removeGeneIDVersions)

# %%
eQTLsAndNumTissuesAffectedBonferroni.describe()
# Out:
#               count
# count  4.487596e+06
# mean   5.061874e+00
# std    8.082678e+00
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    2.000000e+00
# 75%    5.000000e+00
# max    4.800000e+01

# %% [markdown]
# #### Metasoft eQTLs

# %%
eQTLsAndNumTissuesAffectedMetasoft = pd.read_sql_query(
    'SELECT snp AS `variant_id`, gene AS gene_id, mvalTissues AS `count` FROM `v7Metasoft`',
    engine,
    coerce_float=True
)
eQTLsAndNumTissuesAffectedMetasoft['gene_id'] = eQTLsAndNumTissuesAffectedMetasoft['gene_id'].apply(removeGeneIDVersions)

# %%
eQTLsAndNumTissuesAffectedMetasoft.describe()
# Out:
#               count
# count  7.627598e+06
# mean   1.651631e+01
# std    1.561892e+01
# min    0.000000e+00
# 25%    2.000000e+00
# 50%    1.100000e+01
# 75%    3.000000e+01
# max    4.800000e+01

# %% [markdown]
# #### Merge number of tissues affected for the three datasets for same SNP/gene pairs

# %%
eQTLsAndNumTissuesAffectedUncorrected.rename(columns={'count':'countUncorrected'}, inplace=True)
eQTLsAndNumTissuesAffectedBonferroni.rename(columns={'count':'countBonferroniCorrected'}, inplace=True)
eQTLsAndNumTissuesAffectedMetasoft.rename(columns={'count':'countMetasoft'}, inplace=True)

# %%
merge1 = pd.merge(eQTLsAndNumTissuesAffectedUncorrected,eQTLsAndNumTissuesAffectedBonferroni, how='left', on=['variant_id','gene_id'])
eQTLsAndNumTissuesAffected = pd.merge(merge1,eQTLsAndNumTissuesAffectedMetasoft, how='left', on=['variant_id','gene_id'])

# %% [markdown]
# Where no tissue affected for Bonferroni-corrected data, replace NA with 0.

# %%
eQTLsAndNumTissuesAffected.fillna(0, inplace=True)

# %%
eQTLsAndNumTissuesAffected
# Out:
#                     variant_id          gene_id  countUncorrected  \
# 0         10_100000625_A_G_b37  ENSG00000138131                 5
# 1         10_100000625_A_G_b37  ENSG00000166024                 4
# 2         10_100000625_A_G_b37  ENSG00000230928                 4
# 3         10_100000645_A_C_b37  ENSG00000138131                 1
# 4         10_100000645_A_C_b37  ENSG00000230928                11
# 5        10_100002841_C_CT_b37  ENSG00000230928                 2
# 6         10_100003242_T_G_b37  ENSG00000166024                 1
# 7         10_100003242_T_G_b37  ENSG00000230928                 1
# 8         10_100003785_T_C_b37  ENSG00000138131                 6
# 9         10_100003785_T_C_b37  ENSG00000166024                 4
# 10        10_100003785_T_C_b37  ENSG00000230928                 3
# 11        10_100004360_G_A_b37  ENSG00000138131                 1
# 12        10_100004360_G_A_b37  ENSG00000230928                11
# 13        10_100004441_G_C_b37  ENSG00000138131                 5
# 14        10_100004441_G_C_b37  ENSG00000166024                 4
# 15        10_100004441_G_C_b37  ENSG00000230928                 4
# 16        10_100004906_C_A_b37  ENSG00000138131                 5
# 17        10_100004906_C_A_b37  ENSG00000166024                 4
# 18        10_100004906_C_A_b37  ENSG00000230928                 5
# 19        10_100004996_G_A_b37  ENSG00000138131                 6
# 20        10_100004996_G_A_b37  ENSG00000166024                 4
# 21        10_100004996_G_A_b37  ENSG00000230928                 3
# 22        10_100005282_C_T_b37  ENSG00000138131                 5
# 23        10_100005282_C_T_b37  ENSG00000166024                 4
# 24        10_100005282_C_T_b37  ENSG00000230928                 5
# 25        10_100007362_G_C_b37  ENSG00000138131                 1
# 26        10_100007362_G_C_b37  ENSG00000230928                11
# 27        10_100008436_G_A_b37  ENSG00000138131                 6
# 28        10_100008436_G_A_b37  ENSG00000166024                 4
# 29        10_100008436_G_A_b37  ENSG00000230928                 3
# ...                        ...              ...               ...
# 7627568     X_99994917_G_A_b37  ENSG00000101811                 1
# 7627569     X_99994917_G_A_b37  ENSG00000102362                21
# 7627570     X_99994917_G_A_b37  ENSG00000223819                 1
# 7627571     X_99995091_A_G_b37  ENSG00000261101                 1
# 7627572     X_99995817_T_C_b37  ENSG00000000003                 2
# 7627573     X_99995817_T_C_b37  ENSG00000007952                 1
# 7627574     X_99995817_T_C_b37  ENSG00000101811                 1
# 7627575     X_99995817_T_C_b37  ENSG00000102362                24
# 7627576     X_99995817_T_C_b37  ENSG00000165194                 1
# 7627577     X_99995817_T_C_b37  ENSG00000223819                 1
# 7627578     X_99995933_C_G_b37  ENSG00000000003                 3
# 7627579     X_99995933_C_G_b37  ENSG00000101811                 1
# 7627580     X_99995933_C_G_b37  ENSG00000102362                26
# 7627581     X_99995933_C_G_b37  ENSG00000223819                 1
# 7627582     X_99997406_T_G_b37  ENSG00000000003                 2
# 7627583     X_99997406_T_G_b37  ENSG00000007952                 1
# 7627584     X_99997406_T_G_b37  ENSG00000101811                 1
# 7627585     X_99997406_T_G_b37  ENSG00000102362                26
# 7627586     X_99997406_T_G_b37  ENSG00000223819                 1
# 7627587     X_99998829_C_T_b37  ENSG00000000003                 2
# 7627588     X_99998829_C_T_b37  ENSG00000007952                 1
# 7627589     X_99998829_C_T_b37  ENSG00000101811                 1
# 7627590     X_99998829_C_T_b37  ENSG00000102362                25
# 7627591     X_99998829_C_T_b37  ENSG00000165194                 1
# 7627592     X_99998829_C_T_b37  ENSG00000223819                 1
# 7627593     X_99999349_G_A_b37  ENSG00000000003                 2
# 7627594     X_99999349_G_A_b37  ENSG00000007952                 1
# 7627595     X_99999349_G_A_b37  ENSG00000101811                 1
# 7627596     X_99999349_G_A_b37  ENSG00000102362                24
# 7627597     X_99999349_G_A_b37  ENSG00000223819                 1
#
#          countBonferroniCorrected  countMetasoft
# 0                             4.0              5
# 1                             3.0              9
# 2                             3.0              9
# 3                             1.0              2
# 4                            10.0             29
# 5                             0.0             14
# 6                             0.0              9
# 7                             0.0              4
# 8                             3.0              5
# 9                             2.0             12
# 10                            2.0             10
# 11                            1.0              2
# 12                           10.0             29
# 13                            3.0              5
# 14                            1.0             10
# 15                            2.0              9
# 16                            5.0              6
# 17                            2.0              9
# 18                            3.0              9
# 19                            3.0              5
# 20                            2.0             13
# 21                            2.0              9
# 22                            5.0              5
# 23                            2.0              9
# 24                            3.0              9
# 25                            1.0              2
# 26                           10.0             29
# 27                            3.0              5
# 28                            2.0             13
# 29                            2.0              9
# ...                           ...            ...
# 7627568                       1.0              0
# 7627569                      20.0             21
# 7627570                       1.0              0
# 7627571                       0.0              6
# 7627572                       1.0             15
# 7627573                       0.0             29
# 7627574                       1.0              1
# 7627575                      21.0             20
# 7627576                       0.0              3
# 7627577                       1.0              0
# 7627578                       1.0             15
# 7627579                       1.0              1
# 7627580                      22.0             20
# 7627581                       1.0              0
# 7627582                       2.0             19
# 7627583                       0.0             25
# 7627584                       1.0              1
# 7627585                      21.0             20
# 7627586                       0.0              0
# 7627587                       2.0             15
# 7627588                       0.0             23
# 7627589                       1.0              1
# 7627590                      20.0             21
# 7627591                       0.0              1
# 7627592                       1.0              0
# 7627593                       2.0             11
# 7627594                       0.0             26
# 7627595                       1.0              1
# 7627596                      20.0             20
# 7627597                       1.0              0
#
# [7627598 rows x 5 columns]

# %%
eQTLsAndNumTissuesAffected.describe()
# Out:
#        countUncorrected  countBonferroniCorrected  countMetasoft
# count      7.627598e+06              7.627598e+06   7.627598e+06
# mean       4.822141e+00              2.978086e+00   1.651631e+01
# std        7.782665e+00              6.681433e+00   1.561892e+01
# min        1.000000e+00              0.000000e+00   0.000000e+00
# 25%        1.000000e+00              0.000000e+00   2.000000e+00
# 50%        2.000000e+00              1.000000e+00   1.100000e+01
# 75%        4.000000e+00              2.000000e+00   3.000000e+01
# max        4.800000e+01              4.800000e+01   4.800000e+01

# %%
eQTLsAndNumTissuesAffected.to_csv('../outputFiles/GTExV7/eQTLsAndNumTissuesAffected.txt',
                                 index=False)

# %% [markdown]
# ### Calculate the number of protein coding genes that have a significant eQTL in GTEx V7

# %%
eQTLsAndNumTissuesAffected = pd.read_csv('../outputFiles/GTExV7/eQTLsAndNumTissuesAffected.txt')
eQTLsAndNumTissuesAffected
# Out:
#                     variant_id          gene_id  countUncorrected  \
# 0         10_100000625_A_G_b37  ENSG00000138131                 5
# 1         10_100000625_A_G_b37  ENSG00000166024                 4
# 2         10_100000625_A_G_b37  ENSG00000230928                 4
# 3         10_100000645_A_C_b37  ENSG00000138131                 1
# 4         10_100000645_A_C_b37  ENSG00000230928                11
# 5        10_100002841_C_CT_b37  ENSG00000230928                 2
# 6         10_100003242_T_G_b37  ENSG00000166024                 1
# 7         10_100003242_T_G_b37  ENSG00000230928                 1
# 8         10_100003785_T_C_b37  ENSG00000138131                 6
# 9         10_100003785_T_C_b37  ENSG00000166024                 4
# 10        10_100003785_T_C_b37  ENSG00000230928                 3
# 11        10_100004360_G_A_b37  ENSG00000138131                 1
# 12        10_100004360_G_A_b37  ENSG00000230928                11
# 13        10_100004441_G_C_b37  ENSG00000138131                 5
# 14        10_100004441_G_C_b37  ENSG00000166024                 4
# 15        10_100004441_G_C_b37  ENSG00000230928                 4
# 16        10_100004906_C_A_b37  ENSG00000138131                 5
# 17        10_100004906_C_A_b37  ENSG00000166024                 4
# 18        10_100004906_C_A_b37  ENSG00000230928                 5
# 19        10_100004996_G_A_b37  ENSG00000138131                 6
# 20        10_100004996_G_A_b37  ENSG00000166024                 4
# 21        10_100004996_G_A_b37  ENSG00000230928                 3
# 22        10_100005282_C_T_b37  ENSG00000138131                 5
# 23        10_100005282_C_T_b37  ENSG00000166024                 4
# 24        10_100005282_C_T_b37  ENSG00000230928                 5
# 25        10_100007362_G_C_b37  ENSG00000138131                 1
# 26        10_100007362_G_C_b37  ENSG00000230928                11
# 27        10_100008436_G_A_b37  ENSG00000138131                 6
# 28        10_100008436_G_A_b37  ENSG00000166024                 4
# 29        10_100008436_G_A_b37  ENSG00000230928                 3
# ...                        ...              ...               ...
# 7627568     X_99994917_G_A_b37  ENSG00000101811                 1
# 7627569     X_99994917_G_A_b37  ENSG00000102362                21
# 7627570     X_99994917_G_A_b37  ENSG00000223819                 1
# 7627571     X_99995091_A_G_b37  ENSG00000261101                 1
# 7627572     X_99995817_T_C_b37  ENSG00000000003                 2
# 7627573     X_99995817_T_C_b37  ENSG00000007952                 1
# 7627574     X_99995817_T_C_b37  ENSG00000101811                 1
# 7627575     X_99995817_T_C_b37  ENSG00000102362                24
# 7627576     X_99995817_T_C_b37  ENSG00000165194                 1
# 7627577     X_99995817_T_C_b37  ENSG00000223819                 1
# 7627578     X_99995933_C_G_b37  ENSG00000000003                 3
# 7627579     X_99995933_C_G_b37  ENSG00000101811                 1
# 7627580     X_99995933_C_G_b37  ENSG00000102362                26
# 7627581     X_99995933_C_G_b37  ENSG00000223819                 1
# 7627582     X_99997406_T_G_b37  ENSG00000000003                 2
# 7627583     X_99997406_T_G_b37  ENSG00000007952                 1
# 7627584     X_99997406_T_G_b37  ENSG00000101811                 1
# 7627585     X_99997406_T_G_b37  ENSG00000102362                26
# 7627586     X_99997406_T_G_b37  ENSG00000223819                 1
# 7627587     X_99998829_C_T_b37  ENSG00000000003                 2
# 7627588     X_99998829_C_T_b37  ENSG00000007952                 1
# 7627589     X_99998829_C_T_b37  ENSG00000101811                 1
# 7627590     X_99998829_C_T_b37  ENSG00000102362                25
# 7627591     X_99998829_C_T_b37  ENSG00000165194                 1
# 7627592     X_99998829_C_T_b37  ENSG00000223819                 1
# 7627593     X_99999349_G_A_b37  ENSG00000000003                 2
# 7627594     X_99999349_G_A_b37  ENSG00000007952                 1
# 7627595     X_99999349_G_A_b37  ENSG00000101811                 1
# 7627596     X_99999349_G_A_b37  ENSG00000102362                24
# 7627597     X_99999349_G_A_b37  ENSG00000223819                 1
#
#          countBonferroniCorrected  countMetasoft
# 0                             4.0              5
# 1                             3.0              9
# 2                             3.0              9
# 3                             1.0              2
# 4                            10.0             29
# 5                             0.0             14
# 6                             0.0              9
# 7                             0.0              4
# 8                             3.0              5
# 9                             2.0             12
# 10                            2.0             10
# 11                            1.0              2
# 12                           10.0             29
# 13                            3.0              5
# 14                            1.0             10
# 15                            2.0              9
# 16                            5.0              6
# 17                            2.0              9
# 18                            3.0              9
# 19                            3.0              5
# 20                            2.0             13
# 21                            2.0              9
# 22                            5.0              5
# 23                            2.0              9
# 24                            3.0              9
# 25                            1.0              2
# 26                           10.0             29
# 27                            3.0              5
# 28                            2.0             13
# 29                            2.0              9
# ...                           ...            ...
# 7627568                       1.0              0
# 7627569                      20.0             21
# 7627570                       1.0              0
# 7627571                       0.0              6
# 7627572                       1.0             15
# 7627573                       0.0             29
# 7627574                       1.0              1
# 7627575                      21.0             20
# 7627576                       0.0              3
# 7627577                       1.0              0
# 7627578                       1.0             15
# 7627579                       1.0              1
# 7627580                      22.0             20
# 7627581                       1.0              0
# 7627582                       2.0             19
# 7627583                       0.0             25
# 7627584                       1.0              1
# 7627585                      21.0             20
# 7627586                       0.0              0
# 7627587                       2.0             15
# 7627588                       0.0             23
# 7627589                       1.0              1
# 7627590                      20.0             21
# 7627591                       0.0              1
# 7627592                       1.0              0
# 7627593                       2.0             11
# 7627594                       0.0             26
# 7627595                       1.0              1
# 7627596                      20.0             20
# 7627597                       1.0              0
#
# [7627598 rows x 5 columns]

# %%
affectedGenes = eQTLsAndNumTissuesAffected['gene_id'].unique()

# %%
len(affectedGenes)
# Out:
# 31385

# %%
PCGenes = pd.read_csv('../datasets/geneLists/Ensembl/EnsV75ProteinCodingGenes1-Y.txt', sep='\t')
PCGenes.head()
# Out:
#    Ensembl Gene ID Chromosome Name  Gene Start (bp)  Gene End (bp)  Strand
# 0  ENSG00000215405              15         20737094       20747114      -1
# 1  ENSG00000268343              15         21004687       21005367       1
# 2  ENSG00000230031              15         21040701       21071643      -1
# 3  ENSG00000138593              15         49280673       49338760      -1
# 4  ENSG00000268531              15         22011370       22012050       1

# %%
len(PCGenes[PCGenes['Ensembl Gene ID'].isin(affectedGenes)])
# Out:
# 18199
