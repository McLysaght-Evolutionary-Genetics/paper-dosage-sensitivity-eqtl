# %% [markdown]
# # Ohnologs & eQTLs

# %% [markdown]
# ### Background
#
# Enrichment for eQTLs of ohnologs and nonohnologs.

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import re
import os.path

# %% [markdown]
# ### Functions

# %%
def removeGeneIDVersions(text):
    return re.findall('(ENSG\d+)', text)[0]

# %% [markdown]
# ### Input/Output files

# %% [markdown]
# ---

# %% [markdown]
# ### eQTL affected tissues per gene
# [Back to top](#Outline)

# %%
genesTestedForeQTLsWithNumberOfTissues = pd.read_csv('../outputFiles/GTExV7/genesTestedWithNumberOfTissues.csv')
genesTestedForeQTLsWithNumberOfTissues.head()
# Out:
#    expressedTissues  Ensembl Gene ID
# 0                48  ENSG00000272186
# 1                48  ENSG00000117748
# 2                48  ENSG00000130856
# 3                48  ENSG00000169446
# 4                48  ENSG00000013573

# %%
len(genesTestedForeQTLsWithNumberOfTissues)
# Out:
# 38187

# %%
genesTestedForeQTLsWithNumberOfMergedTissues = pd.read_csv('../outputFiles/GTExV7/genesTestedWithNumberOfMergedTissues.csv')
genesTestedForeQTLsWithNumberOfMergedTissues.head()
# Out:
#    expressedTissues  Ensembl Gene ID
# 0                26  ENSG00000170604
# 1                26  ENSG00000178458
# 2                26  ENSG00000141425
# 3                26  ENSG00000117115
# 4                26  ENSG00000105204

# %%
PCGenes = pd.read_csv('../datasets/geneLists/Ensembl/EnsV75ProteinCodingGenes1-Y.txt', sep='\t')
PCGenes.head()
# Out:
#    Ensembl Gene ID Chromosome Name  Gene Start (bp)  Gene End (bp)  Strand
# 0  ENSG00000215405              15         20737094       20747114      -1
# 1  ENSG00000268343              15         21004687       21005367       1
# 2  ENSG00000230031              15         21040701       21071643      -1
# 3  ENSG00000138593              15         49280673       49338760      -1
# 4  ENSG00000268531              15         22011370       22012050       1

# %%
len(PCGenes)
# Out:
# 20314

# %%
genesTestedForeQTLsWithNumberOfTissues = pd.merge(genesTestedForeQTLsWithNumberOfTissues, PCGenes, on="Ensembl Gene ID")
genesTestedForeQTLsWithNumberOfMergedTissues = pd.merge(genesTestedForeQTLsWithNumberOfMergedTissues, PCGenes, on="Ensembl Gene ID")

# %%
len(genesTestedForeQTLsWithNumberOfTissues)
# Out:
# 19067

# %% [markdown]
# ##### Bonferroni-corrected

# %%
genesWitheQTLTissueCountBonferroni = pd.read_csv('../outputFiles/GTExV7/genesWithNumberOfBonferroniAffectedTissues.csv', index_col = 0)
genesWitheQTLTissueCountBonferroni.head()
# Out:
#    Ensembl Gene ID  affectedTissues
# 0  ENSG00000138593                4
# 1  ENSG00000166351                1
# 2  ENSG00000168675                1
# 3  ENSG00000188992               13
# 4  ENSG00000185272                8

# %%
genesWitheQTLTissueCountBonferroni = pd.merge(genesWitheQTLTissueCountBonferroni, genesTestedForeQTLsWithNumberOfTissues, on='Ensembl Gene ID', how='right')
genesWitheQTLTissueCountBonferroni
# Out:
#        Ensembl Gene ID  affectedTissues  expressedTissues Chromosome Name  \
# 0      ENSG00000138593              4.0                48              15
# 1      ENSG00000166351              1.0                 1              21
# 2      ENSG00000168675              1.0                47              18
# 15            18884700       18965897       1
# 16            13726659       13764557       1
# 17            44388353       44500123      -1
# 18            49447853       49660066       1
# 19            18965971       18985265      -1
# 20            63334831       63364114       1
# 21            19161284       19191703      -1
# 22            91073157       91188577       1
# 23            41099284       41106767       1
# 24            54967427       54979518       1
# 25            19273580       19639690       1
# 26            22892005       23006016       1
# 27            44313292       44333658      -1
# 28            19641433       19858197      -1
# 29            44330655       44337456       1
# ...                ...            ...     ...
# 19037         59210617       59211667       1
# 19038        125616188      125619762       1
# 19039         11361605       11363390      -1
# 19040         51273721       51274989       1
# 19041         51303865       51376821       1
# 19042        143174966      143175889       1
# 19043         28471073       28495992      -1
# 19044        121289551      121305481       1
# 19045          4935900        4936922      -1
# 19046         97806017       97806946       1
# 19047        109012635      109035364      -1
# 19048         82380935       82390035       1
# 19049         20691791       20692964       1
# 19050        151934652      151938240      -1
# 19051        113650469      113651222       1
# 19052         49407734       49433342       1
# 19053        143632259      143633372       1
# 19054        142113704      142122488       1
# 19055         74987094       74993252      -1
# 19056         29476288       29479154      -1
# 19057         23507264       23528706       1
# 19058         48304500       48322308      -1
# 19059         34256507       34257278       1
# 19060          2153768        2182439      -1
# 19061         16668281       16672793       1
# 19062         57791353       57949088       1
# 19063         49215065       49229291      -1
# 19064         18794370       18795033       1
# 19065        148287657      148312952       1
# 19066         18194384       18195827       1
#
# [19067 rows x 7 columns]

# %%
genesWitheQTLTissueCountBonferroni['affectedTissues'].fillna(0, inplace=True)

# %% [markdown]
# ##### Ohnologs

# %%
ohnologsRelaxed = pd.read_csv('../datasets/geneLists/Singh and Isambert/hsapiens.Pairs.Relaxed.2R.Ens75.1-Y.txt')
ohnologsRelaxed.head()
# Out:
#    Ensembl Gene ID
# 0  ENSG00000164236
# 1  ENSG00000147465
# 2  ENSG00000095464
# 3  ENSG00000078804
# 4  ENSG00000155744

# %%
SSDsRelaxedOhnos = pd.read_csv('../datasets/geneLists/SSDsRelaxedOhnos.txt')
SSDsRelaxedOhnos.head()
# Out:
#    Ensembl Gene ID
# 0  ENSG00000215405
# 1  ENSG00000268343
# 2  ENSG00000230031
# 3  ENSG00000268531
# 4  ENSG00000233917

# %%
singletons = pd.read_csv('../datasets/geneLists/singletons.txt')
singletons.head()
# Out:
#    Ensembl Gene ID
# 0  ENSG00000269182
# 1  ENSG00000155304
# 2  ENSG00000243440
# 3  ENSG00000180530
# 4  ENSG00000259458

# %%
genesWitheQTLTissueCountBonferroni.loc[:, 'type'] = ''
genesWitheQTLTissueCountBonferroni.loc[genesWitheQTLTissueCountBonferroni['Ensembl Gene ID'].isin(ohnologsRelaxed['Ensembl Gene ID']) , 'type'] = 'ohno'
genesWitheQTLTissueCountBonferroni.loc[genesWitheQTLTissueCountBonferroni['Ensembl Gene ID'].isin(SSDsRelaxedOhnos['Ensembl Gene ID']) , 'type'] = 'SSD'
genesWitheQTLTissueCountBonferroni.loc[genesWitheQTLTissueCountBonferroni['Ensembl Gene ID'].isin(singletons['Ensembl Gene ID']) , 'type'] = 'singleton'
genesWitheQTLTissueCountBonferroni.groupby('type').describe()
# Out:
#           Gene End (bp)                                                    \
#                   count          mean           std      min          25%
# type
# SSD              6777.0  7.361875e+07  5.627181e+07  70008.0  30894236.00
# ohno             6550.0  7.597553e+07  5.583925e+07  31427.0  32878425.75
# singleton        5740.0  7.385908e+07  5.555843e+07  69452.0  31880189.75
#
#                                                  Gene Start (bp)  \
#                   50%           75%          max           count
# type
# SSD        56667898.0  1.095848e+08  249214145.0          6777.0
# ohno       61947334.0  1.134841e+08  246670614.0          6550.0
# singleton  58760361.0  1.104328e+08  249143716.0          5740.0
#
#                          ...  affectedTissues       expressedTissues  \
#                    mean  ...              75%   max            count
# type                     ...
# SSD        7.356490e+07  ...             11.0  48.0           6777.0
# ohno       7.587494e+07  ...              9.0  48.0           6550.0
# singleton  7.381176e+07  ...             12.0  48.0           5740.0
#
#
#                 mean        std  min   25%   50%   75%   max
# type
# SSD        39.105947  15.847822  1.0  40.0  48.0  48.0  48.0
# ohno       43.522290  10.591560  1.0  46.0  48.0  48.0  48.0
# singleton  41.820383  13.721230  1.0  47.0  48.0  48.0  48.0
#
# [3 rows x 40 columns]

# %%
genesWitheQTLTissueCountBonferroni.head()
# Out:
#    Ensembl Gene ID  affectedTissues  expressedTissues Chromosome Name  \
# 0  ENSG00000138593              4.0                48              15
# 1  ENSG00000166351              1.0                 1              21
# 2  ENSG00000168675              1.0                47              18
# 3  ENSG00000188992             13.0                30              21
# 4  ENSG00000185272              8.0                48              21
#
#    Gene Start (bp)  Gene End (bp)  Strand  type
# 0         49280673       49338760      -1  ohno
# 1         14982498       15013906       1   SSD
# 2         13217497       13652754       1   SSD
# 3         15481134       15583166      -1   SSD
# 4         15588451       15600693       1  ohno

# %%
genesWitheQTLTissueCountBonferroni['propOfExpressedAffectedByeQTL'] = genesWitheQTLTissueCountBonferroni['affectedTissues'] / genesWitheQTLTissueCountBonferroni['expressedTissues']

# %%
genesWitheQTLTissueCountBonferroni.groupby('type').describe()
# Out:
#           Gene End (bp)                                                    \
#                   count          mean           std      min          25%
# type
# SSD              6777.0  7.361875e+07  5.627181e+07  70008.0  30894236.00
# ohno             6550.0  7.597553e+07  5.583925e+07  31427.0  32878425.75
# singleton        5740.0  7.385908e+07  5.555843e+07  69452.0  31880189.75
#
#                                                  Gene Start (bp)  \
#                   50%           75%          max           count
# type
# SSD        56667898.0  1.095848e+08  249214145.0          6777.0
# ohno       61947334.0  1.134841e+08  246670614.0          6550.0
# singleton  58760361.0  1.104328e+08  249143716.0          5740.0
#
#                         ...  expressedTissues        \
#                    mean ...               75%   max
# type                    ...
# SSD        7.356490e+07 ...              48.0  48.0
# ohno       7.587494e+07 ...              48.0  48.0
# singleton  7.381176e+07 ...              48.0  48.0
#
#           propOfExpressedAffectedByeQTL                                     \
#                                   count      mean       std  min       25%
# type
# SSD                              6777.0  0.204547  0.252103  0.0  0.020833
# ohno                             6550.0  0.151683  0.177107  0.0  0.030303
# singleton                        5740.0  0.200093  0.242668  0.0  0.020833
#
#
#                 50%       75%  max
# type
# SSD        0.104167  0.291667  1.0
# ohno       0.086957  0.208333  1.0
# singleton  0.104167  0.291667  1.0
#
# [3 rows x 48 columns]

# %%
genesWitheQTLTissueCountBonferroni[genesWitheQTLTissueCountBonferroni['affectedTissues']>0].groupby('type').describe()
# Out:
#           Gene End (bp)                                                    \
#                   count          mean           std      min          25%
# type
# SSD              5473.0  7.391207e+07  5.629434e+07  73545.0  31054296.00
# ohno             5604.0  7.573204e+07  5.583758e+07  31427.0  32638860.25
# singleton        4661.0  7.372066e+07  5.589631e+07  69452.0  31499709.00
#
#                                                  Gene Start (bp)  \
#                   50%           75%          max           count
# type
# SSD        57233335.0  1.097808e+08  249153343.0          5473.0
# ohno       61984211.5  1.133391e+08  246670614.0          5604.0
# singleton  58554431.0  1.104216e+08  248903150.0          4661.0
#
#                         ...  expressedTissues        \
#                    mean ...               75%   max
# type                    ...
# SSD        7.385313e+07 ...              48.0  48.0
# ohno       7.562491e+07 ...              48.0  48.0
# singleton  7.366924e+07 ...              48.0  48.0
#
#           propOfExpressedAffectedByeQTL                                        \
#                                   count      mean       std       min     25%
# type
# SSD                              5473.0  0.253282  0.257596  0.020833  0.0625
# ohno                             5604.0  0.177289  0.179228  0.020833  0.0625
# singleton                        4661.0  0.246414  0.247197  0.020833  0.0625
#
#
#                 50%       75%  max
# type
# SSD        0.145833  0.354167  1.0
# ohno       0.120000  0.229167  1.0
# singleton  0.145833  0.354167  1.0
#
# [3 rows x 48 columns]

# %%
genesWitheQTLTissueCountBonferroni.to_csv("../outputFiles/genesWitheQTLTissueCountBonferroniAndOhnologStatus.csv", sep='\t')

# %% [markdown]
# ##### Metasoft

# %%
genesWitheQTLTissueCountMetasoft = pd.read_csv('../outputFiles/GTExV7/genesWithNumberOfMetasoftAffectedTissues.csv', index_col = 0)
genesWitheQTLTissueCountMetasoft = pd.merge(genesWitheQTLTissueCountMetasoft, genesTestedForeQTLsWithNumberOfTissues, on='Ensembl Gene ID', how='right')
genesWitheQTLTissueCountMetasoft['affectedTissues'].fillna(0, inplace=True)
genesWitheQTLTissueCountMetasoft['propOfExpressedAffectedByeQTL'] = genesWitheQTLTissueCountMetasoft['affectedTissues'] / genesWitheQTLTissueCountMetasoft['expressedTissues']
genesWitheQTLTissueCountMetasoft.loc[:, 'type'] = ''
genesWitheQTLTissueCountMetasoft.loc[genesWitheQTLTissueCountMetasoft['Ensembl Gene ID'].isin(ohnologsRelaxed['Ensembl Gene ID']) , 'type'] = 'ohno'
genesWitheQTLTissueCountMetasoft.loc[genesWitheQTLTissueCountMetasoft['Ensembl Gene ID'].isin(SSDsRelaxedOhnos['Ensembl Gene ID']) , 'type'] = 'SSD'
genesWitheQTLTissueCountMetasoft.loc[genesWitheQTLTissueCountMetasoft['Ensembl Gene ID'].isin(singletons['Ensembl Gene ID']) , 'type'] = 'singleton'
genesWitheQTLTissueCountMetasoft
# Out:
#        Ensembl Gene ID  affectedTissues  expressedTissues Chromosome Name  \
# 6             22736246       22746002       1                       0.250000
# 7             49398268       49447858      -1                       0.916667
# 8             15857549       15955723      -1                       0.083333
# 9             15964251       16031142      -1                       0.285714
# 10            22833395       22873892       1                       1.000000
# 11            16333556       16437321      -1                       0.250000
# 12            41028082       41048049      -1                       0.979167
# 13            62929371       62937490      -1                       0.250000
# 14            41056218       41059906       1                       0.062500
# 15            41060067       41099675      -1                       1.000000
# 16            13663346       13726662      -1                       0.895833
# 17            17102344       17252377       1                       0.187500
# 18            44259081       44339220      -1                       0.833333
# 19            18884700       18965897       1                       0.400000
# 20            13726659       13764557       1                       0.979167
# 21            44388353       44500123      -1                       0.979167
# 22            49447853       49660066       1                       0.875000
# 23            18965971       18985265      -1                       0.250000
# 24            63334831       63364114       1                       0.833333
# 25            19161284       19191703      -1                       0.416667
# 26            91073157       91188577       1                       0.979167
# 27            41099284       41106767       1                       1.000000
# 28            54967427       54979518       1                       1.000000
# 29            19273580       19639690       1                       0.755556
# ...                ...            ...     ...                            ...
# 19037        121289551      121305481       1                       0.000000
# 19038          4935900        4936922      -1                       0.000000
# 19039         97806017       97806946       1                       0.000000
# 19040        109012635      109035364      -1                       0.000000
# 19041         82380935       82390035       1                       0.000000
# 19042         20691791       20692964       1                       0.000000
# 19043        151934652      151938240      -1                       0.000000
# 19044        113650469      113651222       1                       0.000000
# 19045         49407734       49433342       1                       0.000000
# 19046        143632259      143633372       1                       0.000000
# 19047         29956421       29961726       1                       0.000000
# 19048        142113704      142122488       1                       0.000000
# 19049         74987094       74993252      -1                       0.000000
# 19050         29476288       29479154      -1                       0.000000
# 19051        138760944      138763734      -1                       0.000000
# 19052         23507264       23528706       1                       0.000000
# 19053         48304500       48322308      -1                       0.000000
# 19054        141290131      141293076      -1                       0.000000
# 19055         34256507       34257278       1                       0.000000
# 19056         39355699       39361956       1                       0.000000
# 19057        132021520      132022635      -1                       0.000000
# 19058          4711928        4721314      -1                       0.000000
# 19059          2153768        2182439      -1                       0.000000
# 19060         16668281       16672793       1                       0.000000
# 19061        128181282      128186091      -1                       0.000000
# 19062         57791353       57949088       1                       0.000000
# 19063         49215065       49229291      -1                       0.000000
# 19064         18794370       18795033       1                       0.000000
# 19065        148287657      148312952       1                       0.000000
# 19066         18194384       18195827       1                       0.000000
#
#             type
# 0           ohno
# 1            SSD
# 2            SSD
# 3            SSD
# 4           ohno
# 5      singleton
# 6            SSD
# 7            SSD
# 8            SSD
# 9      singleton
# 10           SSD
# 11     singleton
# 12          ohno
# 13     singleton
# 14     singleton
# 15           SSD
# 16           SSD
# 17          ohno
# 18           SSD
# 19           SSD
# 20     singleton
# 21          ohno
# 22           SSD
# 23           SSD
# 24          ohno
# 25     singleton
# 26          ohno
# 27     singleton
# 28           SSD
# 29           SSD
# ...          ...
# 19037  singleton
# 19038        SSD
# 19039        SSD
# 19040        SSD
# 19041  singleton
# 19042        SSD
# 19043        SSD
# 19044       ohno
# 19045  singleton
# 19046        SSD
# 19047  singleton
# 19048        SSD
# 19049  singleton
# 19050        SSD
# 19051        SSD
# 19052        SSD
# 19053        SSD
# 19054        SSD
# 19055  singleton
# 19056        SSD
# 19057        SSD
# 19058  singleton
# 19059        SSD
# 19060  singleton
# 19061        SSD
# 19062        SSD
# 19063  singleton
# 19064        SSD
# 19065  singleton
# 19066        SSD
#
# [19067 rows x 9 columns]

# %%
genesWitheQTLTissueCountMetasoft.groupby('type').describe()
# Out:
#           Gene End (bp)                                                    \
#                   count          mean           std      min          25%
# type
# SSD              6777.0  7.361875e+07  5.627181e+07  70008.0  30894236.00
# ohno             6550.0  7.597553e+07  5.583925e+07  31427.0  32878425.75
# singleton        5740.0  7.385908e+07  5.555843e+07  69452.0  31880189.75
#
#                                                  Gene Start (bp)  \
#                   50%           75%          max           count
# type
# SSD        56667898.0  1.095848e+08  249214145.0          6777.0
# ohno       61947334.0  1.134841e+08  246670614.0          6550.0
# singleton  58760361.0  1.104328e+08  249143716.0          5740.0
#
#                         ...  expressedTissues        \
#                    mean ...               75%   max
# type                    ...
# SSD        7.356490e+07 ...              48.0  48.0
# ohno       7.587494e+07 ...              48.0  48.0
# singleton  7.381176e+07 ...              48.0  48.0
#
#           propOfExpressedAffectedByeQTL                                     \
#                                   count      mean       std  min       25%
# type
# SSD                              6777.0  0.646260  0.373773  0.0  0.296296
# ohno                             6550.0  0.627873  0.342538  0.0  0.312500
# singleton                        5740.0  0.683658  0.367859  0.0  0.354167
#
#
#                 50%       75%  max
# type
# SSD        0.812500  1.000000  1.0
# ohno       0.708333  0.976744  1.0
# singleton  0.888889  1.000000  1.0
#
# [3 rows x 48 columns]

# %%
genesWitheQTLTissueCountMetasoft[genesWitheQTLTissueCountMetasoft['affectedTissues']>0].groupby('type').describe()
# Out:
#           Gene End (bp)                                                   \
#                   count          mean           std      min         25%
# type
# SSD              6161.0  7.376225e+07  5.596415e+07  73545.0  31236510.0
# ohno             6351.0  7.589964e+07  5.584168e+07  31427.0  32809518.5
# singleton        5355.0  7.379700e+07  5.573517e+07  69452.0  31744889.0
#
#                                                 Gene Start (bp)                \
#                   50%          75%          max           count          mean
# type
# SSD        57233335.0  108960832.0  249214145.0          6161.0  7.370443e+07
# ohno       61966203.0  113297392.5  246670614.0          6351.0  7.579709e+07
# singleton  58523735.0  110232462.0  249143716.0          5355.0  7.374805e+07
#
#           ...  expressedTissues       propOfExpressedAffectedByeQTL            \
#           ...               75%   max                         count      mean
# type      ...
# SSD       ...              48.0  48.0                        6161.0  0.710876
# ohno      ...              48.0  48.0                        6351.0  0.647547
# singleton ...              48.0  48.0                        5355.0  0.732810
#
#
#                 std       min       25%       50%       75%  max
# type
# SSD        0.328232  0.020833  0.437500  0.875000  1.000000  1.0
# ohno       0.329040  0.020833  0.354167  0.729167  0.978723  1.0
# singleton  0.330189  0.020833  0.500000  0.916667  1.000000  1.0
#
# [3 rows x 48 columns]

# %%
genesWitheQTLTissueCountMetasoft.to_csv("../outputFiles/genesWitheQTLTissueCountMetasoftAndOhnologStatus.csv", sep='\t')
