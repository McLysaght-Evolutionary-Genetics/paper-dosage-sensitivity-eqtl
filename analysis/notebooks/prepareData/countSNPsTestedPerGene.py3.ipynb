# %% [markdown]
# # Count SNPs tested for eQTL associations

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine
import re
import urllib.request
import os

# %%
engine = create_engine('mysql+mysqlconnector://jupyter:password@localhost:3306/gtex', echo=False)

# %% [markdown]
# ### Functions

# %% [markdown]
# Remove version numbers from Ensembl Gene IDs e.g. 'ENSG000000001.8' to 'ENSG000000001'. Enables comparison between IDs from different sources

# %%
def removeGeneIDVersions(text):
    return re.findall('(ENSG\d+)', text)[0]

# %% [markdown]
# ### Constants

# %% [markdown]
# #### List of GTEx tissues

# %%
tissues = ['Adipose - Subcutaneous',
 'Adipose - Visceral (Omentum)',
 'Adrenal Gland',
 'Artery - Aorta',
 'Artery - Coronary',
 'Artery - Tibial',
 'Brain - Amygdala',
 'Brain - Anterior cingulate cortex (BA24)',
 'Brain - Caudate (basal ganglia)',
 'Brain - Cerebellar Hemisphere',
 'Brain - Cerebellum',
 'Brain - Cortex',
 'Brain - Frontal Cortex (BA9)',
 'Brain - Hippocampus',
 'Brain - Hypothalamus',
 'Brain - Nucleus accumbens (basal ganglia)',
 'Brain - Putamen (basal ganglia)',
 'Brain - Spinal cord (cervical c-1)',
 'Brain - Substantia nigra',
 'Breast - Mammary Tissue',
 'Cells - EBV-transformed lymphocytes',
 'Cells - Transformed fibroblasts',
 'Colon - Sigmoid',
 'Colon - Transverse',
 'Esophagus - Gastroesophageal Junction',
 'Esophagus - Mucosa',
 'Esophagus - Muscularis',
 'Heart - Atrial Appendage',
 'Heart - Left Ventricle',
 'Liver',
 'Lung',
 'Minor Salivary Gland',
 'Muscle - Skeletal',
 'Nerve - Tibial',
 'Ovary',
 'Pancreas',
 'Pituitary',
 'Prostate',
 'Skin - Not Sun Exposed (Suprapubic)',
 'Skin - Sun Exposed (Lower leg)',
 'Small Intestine - Terminal Ileum',
 'Spleen',
 'Stomach',
 'Testis',
 'Thyroid',
 'Uterus',
 'Vagina',
 'Whole Blood']

# %% [markdown]
# ---

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Download and count all tested SNP-gene associations for each GTEx tissue

# %%
for tissue in tissues:
    print(tissue)
    tissue_url = tissue.replace(' - ','_').replace('(','').replace(')','').replace(' ','_')
    print('Downloading '+tissue_url+'.allpairs.txt.gz...')
    urllib.request.urlretrieve('https://storage.googleapis.com/gtex_analysis_v7/single_tissue_eqtl_data/all_snp_gene_associations/'+tissue_url+'.allpairs.txt.gz', tissue_url+'.allpairs.txt.gz')
    print('Unzipping '+tissue_url+'.allpairs.txt.gz...')
    os.system('gunzip '+ tissue_url+'.allpairs.txt.gz')
    print('Counting...')
    os.system('xsv select -d "\t" "gene_id" '+tissue_url+'.allpairs.txt | xsv frequency --asc  --limit 0 > "../../outputFiles/GTExV7/numTestedSNPs/'+tissue+'.txt"')
    print('Deleting '+tissue_url+'.allpairs.txt...')
    os.remove(tissue_url+'.allpairs.txt')
# Out:
# Lung
# Downloading Lung.allpairs.txt.gz...
# Unzipping Lung.allpairs.txt.gz...
# Counting...
# Deleting Lung.allpairs.txt...
# Minor Salivary Gland
# Downloading Minor_Salivary_Gland.allpairs.txt.gz...
# Unzipping Minor_Salivary_Gland.allpairs.txt.gz...
# Counting...
# Deleting Minor_Salivary_Gland.allpairs.txt...
# Muscle - Skeletal
# Downloading Muscle_Skeletal.allpairs.txt.gz...
# Unzipping Muscle_Skeletal.allpairs.txt.gz...
# Counting...
# Deleting Muscle_Skeletal.allpairs.txt...
# Nerve - Tibial
# Downloading Nerve_Tibial.allpairs.txt.gz...
# Unzipping Nerve_Tibial.allpairs.txt.gz...
# Counting...
# Deleting Nerve_Tibial.allpairs.txt...
# Ovary
# Downloading Ovary.allpairs.txt.gz...
# Unzipping Ovary.allpairs.txt.gz...
# Counting...
# Deleting Ovary.allpairs.txt...
# Pancreas
# Downloading Pancreas.allpairs.txt.gz...
# Unzipping Pancreas.allpairs.txt.gz...
# Counting...
# Deleting Pancreas.allpairs.txt...
# Pituitary
# Downloading Pituitary.allpairs.txt.gz...
# Unzipping Pituitary.allpairs.txt.gz...
# Counting...
# Deleting Pituitary.allpairs.txt...
# Prostate
# Downloading Prostate.allpairs.txt.gz...
# Unzipping Prostate.allpairs.txt.gz...
# Counting...
# Deleting Prostate.allpairs.txt...
# Skin - Not Sun Exposed (Suprapubic)
# Downloading Skin_Not_Sun_Exposed_Suprapubic.allpairs.txt.gz...
# Unzipping Skin_Not_Sun_Exposed_Suprapubic.allpairs.txt.gz...
# Counting...
# Deleting Skin_Not_Sun_Exposed_Suprapubic.allpairs.txt...
# Skin - Sun Exposed (Lower leg)
# Downloading Skin_Sun_Exposed_Lower_leg.allpairs.txt.gz...
# Unzipping Skin_Sun_Exposed_Lower_leg.allpairs.txt.gz...
# Counting...
# Deleting Skin_Sun_Exposed_Lower_leg.allpairs.txt...
# Small Intestine - Terminal Ileum
# Downloading Small_Intestine_Terminal_Ileum.allpairs.txt.gz...
# Unzipping Small_Intestine_Terminal_Ileum.allpairs.txt.gz...
# Counting...
# Deleting Small_Intestine_Terminal_Ileum.allpairs.txt...
# Spleen
# Downloading Spleen.allpairs.txt.gz...
# Unzipping Spleen.allpairs.txt.gz...
# Counting...
# Deleting Spleen.allpairs.txt...
# Stomach
# Downloading Stomach.allpairs.txt.gz...
# Unzipping Stomach.allpairs.txt.gz...
# Counting...
# Deleting Stomach.allpairs.txt...
# Testis
# Downloading Testis.allpairs.txt.gz...
# Unzipping Testis.allpairs.txt.gz...
# Counting...
# Deleting Testis.allpairs.txt...
# Thyroid
# Downloading Thyroid.allpairs.txt.gz...
# Unzipping Thyroid.allpairs.txt.gz...
# Counting...
# Deleting Thyroid.allpairs.txt...
# Uterus
# Downloading Uterus.allpairs.txt.gz...
# Unzipping Uterus.allpairs.txt.gz...
# Counting...
# Deleting Uterus.allpairs.txt...
# Vagina
# Downloading Vagina.allpairs.txt.gz...
# Unzipping Vagina.allpairs.txt.gz...
# Counting...
# Deleting Vagina.allpairs.txt...
# Whole Blood
# Downloading Whole_Blood.allpairs.txt.gz...
# Unzipping Whole_Blood.allpairs.txt.gz...
# Counting...
# Deleting Whole_Blood.allpairs.txt...

# %% [markdown]
# ### Get number of significant eQTLs for each tissue and calculate proportion of significant SNPs

# %% [markdown]
# #### Ohnologs

# %% [markdown]
# ##### Bonferroni-corrected eQTLs

# %%
allTissuesCombined_ohnologs_bonferroni = pd.DataFrame()
for tissue in tissues:
    print(tissue)
    tissue_url = tissue.replace(' - ','_').replace('(','').replace(')','').replace(' ','_')
    eQTLCountPerGeneBonferroni = pd.read_sql_query(
        'SELECT gene_id as "Ensembl Gene ID", COUNT(*) as eQTLs FROM `v7` WHERE sigAfterBonferroni = 1 AND tissue = "' + tissue + '" GROUP BY gene_id',
        engine,
        coerce_float=True
    )
    numTestedSNPs = pd.read_csv('../../outputFiles/GTExV7/numTestedSNPs/' + tissue + '.txt')
    numTestedSNPs.rename(columns={'value': 'Ensembl Gene ID', 'count': 'SNPs'}, inplace=True)
    genesWitheQTLTissueCountBonferroniAndOhnologStatus = pd.read_csv('../../outputFiles/genesWitheQTLTissueCountBonferroniAndOhnologStatus.csv', sep="\t", index_col="Unnamed: 0")
    
    numTestedSNPs["Ensembl Gene ID"] = numTestedSNPs["Ensembl Gene ID"].apply(removeGeneIDVersions)
    eQTLCountPerGeneBonferroni["Ensembl Gene ID"] = eQTLCountPerGeneBonferroni["Ensembl Gene ID"].apply(removeGeneIDVersions)
    
    merge1 = pd.merge(genesWitheQTLTissueCountBonferroniAndOhnologStatus[['Ensembl Gene ID','type']], numTestedSNPs, how = "inner", on = "Ensembl Gene ID")
    merge2 = pd.merge(merge1, eQTLCountPerGeneBonferroni, how = "left", on = "Ensembl Gene ID")
    merge2['eQTLs'] = merge2['eQTLs'].fillna(0)
    
    merge2['propSignif'] = merge2['eQTLs']/merge2['SNPs']
    merge2['tissue'] = tissue
    allTissuesCombined_ohnologs_bonferroni = allTissuesCombined_ohnologs_bonferroni.append(merge2)
# Out:
# Adipose - Subcutaneous
# Adipose - Visceral (Omentum)
# Adrenal Gland
# Artery - Aorta
# Artery - Coronary
# Artery - Tibial
# Brain - Amygdala
# Brain - Anterior cingulate cortex (BA24)
# Brain - Caudate (basal ganglia)
# Brain - Cerebellar Hemisphere
# Brain - Cerebellum
# Brain - Cortex
# Brain - Frontal Cortex (BA9)
# Brain - Hippocampus
# Brain - Hypothalamus
# Brain - Nucleus accumbens (basal ganglia)
# Brain - Putamen (basal ganglia)
# Brain - Spinal cord (cervical c-1)
# Brain - Substantia nigra
# Breast - Mammary Tissue
# Cells - EBV-transformed lymphocytes
# Cells - Transformed fibroblasts
# Colon - Sigmoid
# Colon - Transverse
# Esophagus - Gastroesophageal Junction
# Esophagus - Mucosa
# Esophagus - Muscularis
# Heart - Atrial Appendage
# Heart - Left Ventricle
# Liver
# Lung
# Minor Salivary Gland
# Muscle - Skeletal
# Nerve - Tibial
# Ovary
# Pancreas
# Pituitary
# Prostate
# Skin - Not Sun Exposed (Suprapubic)
# Skin - Sun Exposed (Lower leg)
# Small Intestine - Terminal Ileum
# Spleen
# Stomach
# Testis
# Thyroid
# Uterus
# Vagina
# Whole Blood

# %%
allTissuesCombined_ohnologs_bonferroni
# Out:
#        Ensembl Gene ID       type    field   SNPs  eQTLs  propSignif  \
# 0      ENSG00000138593       ohno  gene_id   5645    0.0    0.000000
# 1      ENSG00000168675        SSD  gene_id   7911    0.0    0.000000
# 2      ENSG00000188992        SSD  gene_id   8607    0.0    0.000000
# 3      ENSG00000185272       ohno  gene_id   8622    0.0    0.000000
# 4      ENSG00000155304  singleton  gene_id   8566    0.0    0.000000
# 5      ENSG00000153575        SSD  gene_id   4601   89.0    0.019344
# 6      ENSG00000180530  singleton  gene_id   8460    0.0    0.000000
# 7      ENSG00000137824       ohno  gene_id   5804   25.0    0.004307
# 8      ENSG00000137880  singleton  gene_id   5790    0.0    0.000000
# 9      ENSG00000104129        SSD  gene_id   5741    1.0    0.000174
# 10     ENSG00000177150        SSD  gene_id   8431    0.0    0.000000
# 11     ENSG00000155313       ohno  gene_id   7272    0.0    0.000000
# 12     ENSG00000101638        SSD  gene_id   7134    0.0    0.000000
# 13     ENSG00000154639        SSD  gene_id   8762    0.0    0.000000
# 14     ENSG00000101654  singleton  gene_id   8431    0.0    0.000000
# 15     ENSG00000078043       ohno  gene_id   7044   15.0    0.002129
# 16     ENSG00000156958        SSD  gene_id   5891    0.0    0.000000
# 17     ENSG00000154640        SSD  gene_id   8876    0.0    0.000000
# 18     ENSG00000140416       ohno  gene_id   7646   79.0    0.010332
# 19     ENSG00000154642  singleton  gene_id   9175    0.0    0.000000
# 20     ENSG00000140577       ohno  gene_id   8399    2.0    0.000238
# 21     ENSG00000166140  singleton  gene_id   5723  433.0    0.075660
# 22     ENSG00000101138        SSD  gene_id   8863    4.0    0.000451
# 23     ENSG00000154645        SSD  gene_id   9301    0.0    0.000000
# 24     ENSG00000068793        SSD  gene_id   4852   34.0    0.007007
# 25     ENSG00000182931  singleton  gene_id   6706    0.0    0.000000
# 26     ENSG00000101365        SSD  gene_id   8212    0.0    0.000000
# 27     ENSG00000167216        SSD  gene_id   7041  323.0    0.045874
# 28     ENSG00000124116  singleton  gene_id   6832  671.0    0.098214
# 29     ENSG00000087589       ohno  gene_id   8902    0.0    0.000000
# ...                ...        ...      ...    ...    ...         ...
# 14804  ENSG00000187475        SSD  gene_id   7753    0.0    0.000000
# 14805  ENSG00000268000  singleton  gene_id   8139    0.0    0.000000
# 14806  ENSG00000181616        SSD  gene_id  11284    0.0    0.000000
# 14807  ENSG00000185990        SSD  gene_id   2336    0.0    0.000000
# 14808  ENSG00000182393        SSD  gene_id   7281    0.0    0.000000
# 14809  ENSG00000254019  singleton  gene_id   7995    0.0    0.000000
# 14810  ENSG00000175779  singleton  gene_id   7972    0.0    0.000000
# 14811  ENSG00000175485  singleton  gene_id  10350    0.0    0.000000
# 14812  ENSG00000184321        SSD  gene_id  11982    0.0    0.000000
# 14813  ENSG00000156575        SSD  gene_id   7207    0.0    0.000000
# 14814  ENSG00000221937        SSD  gene_id   5344    0.0    0.000000
# 14815  ENSG00000105370  singleton  gene_id   9585    0.0    0.000000
# 14816  ENSG00000182572        SSD  gene_id   7191    0.0    0.000000
# 14817  ENSG00000176895        SSD  gene_id  12141    0.0    0.000000
# 14818  ENSG00000240247        SSD  gene_id   9793    0.0    0.000000
# 14819  ENSG00000187918        SSD  gene_id  11780    0.0    0.000000
# 14820  ENSG00000176922  singleton  gene_id  11980    0.0    0.000000
# 14821  ENSG00000249160  singleton  gene_id   8492    0.0    0.000000
# 14822  ENSG00000167359        SSD  gene_id  11815    0.0    0.000000
# 14823  ENSG00000184881        SSD  gene_id  12070    0.0    0.000000
# 14824  ENSG00000255307        SSD  gene_id  10601    0.0    0.000000
# 14825  ENSG00000171987  singleton  gene_id  11519    0.0    0.000000
# 14826  ENSG00000205300  singleton  gene_id   8719    0.0    0.000000
# 14827  ENSG00000221996        SSD  gene_id  11514    0.0    0.000000
# 14828  ENSG00000197790        SSD  gene_id  11539    0.0    0.000000
# 14829  ENSG00000184698        SSD  gene_id  12039    0.0    0.000000
# 14830  ENSG00000206047        SSD  gene_id  10043    0.0    0.000000
# 14831  ENSG00000176239        SSD  gene_id  12059    0.0    0.000000
# 14832  ENSG00000182070        SSD  gene_id  12441    0.0    0.000000
# 14833  ENSG00000176893        SSD  gene_id  12167    0.0    0.000000
#
#                        tissue
# 0      Adipose - Subcutaneous
# 1      Adipose - Subcutaneous
# 2      Adipose - Subcutaneous
# 3      Adipose - Subcutaneous
# 4      Adipose - Subcutaneous
# 5      Adipose - Subcutaneous
# 6      Adipose - Subcutaneous
# 7      Adipose - Subcutaneous
# 8      Adipose - Subcutaneous
# 9      Adipose - Subcutaneous
# 10     Adipose - Subcutaneous
# 11     Adipose - Subcutaneous
# 12     Adipose - Subcutaneous
# 13     Adipose - Subcutaneous
# 14     Adipose - Subcutaneous
# 15     Adipose - Subcutaneous
# 16     Adipose - Subcutaneous
# 17     Adipose - Subcutaneous
# 18     Adipose - Subcutaneous
# 19     Adipose - Subcutaneous
# 20     Adipose - Subcutaneous
# 21     Adipose - Subcutaneous
# 22     Adipose - Subcutaneous
# 23     Adipose - Subcutaneous
# 24     Adipose - Subcutaneous
# 25     Adipose - Subcutaneous
# 26     Adipose - Subcutaneous
# 27     Adipose - Subcutaneous
# 28     Adipose - Subcutaneous
# 29     Adipose - Subcutaneous
# ...                       ...
# 14804             Whole Blood
# 14805             Whole Blood
# 14806             Whole Blood
# 14807             Whole Blood
# 14808             Whole Blood
# 14809             Whole Blood
# 14810             Whole Blood
# 14811             Whole Blood
# 14812             Whole Blood
# 14813             Whole Blood
# 14814             Whole Blood
# 14815             Whole Blood
# 14816             Whole Blood
# 14817             Whole Blood
# 14818             Whole Blood
# 14819             Whole Blood
# 14820             Whole Blood
# 14821             Whole Blood
# 14822             Whole Blood
# 14823             Whole Blood
# 14824             Whole Blood
# 14825             Whole Blood
# 14826             Whole Blood
# 14827             Whole Blood
# 14828             Whole Blood
# 14829             Whole Blood
# 14830             Whole Blood
# 14831             Whole Blood
# 14832             Whole Blood
# 14833             Whole Blood
#
# [790141 rows x 7 columns]

# %%
allTissuesCombined_ohnologs_bonferroni.describe()
# Out:
#                 SNPs          eQTLs     propSignif
# count  790141.000000  790141.000000  790141.000000
# mean     7199.385029      17.646458       0.002585
# std      2238.421046      90.743363       0.012777
# min       119.000000       0.000000       0.000000
# 25%      6104.000000       0.000000       0.000000
# 50%      7160.000000       0.000000       0.000000
# 75%      8125.000000       0.000000       0.000000
# max     28260.000000    4540.000000       0.524256

# %%
allTissuesCombined_ohnologs_bonferroni.to_csv('../../outputFiles/propSNPsSignificanteQTLsOhnologsBonferroni.csv', index=False)

# %% [markdown]
# ##### Metasoft eQTLs

# %%
allTissuesCombined_ohnologs_metasoft = pd.DataFrame()
for tissue in tissues:
    print(tissue)
    tissue_url = tissue.replace(' - ','_').replace('(','').replace(')','').replace(' ','_')
    eQTLCountPerGeneMetasoft = pd.read_sql_query(
        'SELECT gene as "Ensembl Gene ID", COUNT(*) as eQTLs FROM `v7Metasoft` WHERE `mval_' + tissue_url + '` > 0.9 GROUP BY gene',
        engine,
        coerce_float=True
    )
    numTestedSNPs = pd.read_csv('../../outputFiles/GTExV7/numTestedSNPs/' + tissue + '.txt')
    numTestedSNPs.rename(columns={'value': 'Ensembl Gene ID', 'count': 'SNPs'}, inplace=True)
    genesWitheQTLTissueCountMetasoftAndOhnologStatus = pd.read_csv('../../outputFiles/genesWitheQTLTissueCountMetasoftAndOhnologStatus.csv', sep="\t", index_col="Unnamed: 0")
    
    numTestedSNPs["Ensembl Gene ID"] = numTestedSNPs["Ensembl Gene ID"].apply(removeGeneIDVersions)
    eQTLCountPerGeneMetasoft["Ensembl Gene ID"] = eQTLCountPerGeneMetasoft["Ensembl Gene ID"].apply(removeGeneIDVersions)
    
    merge1 = pd.merge(genesWitheQTLTissueCountMetasoftAndOhnologStatus[['Ensembl Gene ID','type']], numTestedSNPs, how = "inner", on = "Ensembl Gene ID")
    merge2 = pd.merge(merge1, eQTLCountPerGeneMetasoft, how = "left", on = "Ensembl Gene ID")
    merge2['eQTLs'] = merge2['eQTLs'].fillna(0)
    
    merge2['propSignif'] = merge2['eQTLs']/merge2['SNPs']
    merge2['tissue'] = tissue
    allTissuesCombined_ohnologs_metasoft = allTissuesCombined_ohnologs_metasoft.append(merge2)
# Out:
# Adipose - Subcutaneous
# Adipose - Visceral (Omentum)
# Adrenal Gland
# Artery - Aorta
# Artery - Coronary
# Artery - Tibial
# Brain - Amygdala
# Brain - Anterior cingulate cortex (BA24)
# Brain - Caudate (basal ganglia)
# Brain - Cerebellar Hemisphere
# Brain - Cerebellum
# Brain - Cortex
# Brain - Frontal Cortex (BA9)
# Brain - Hippocampus
# Brain - Hypothalamus
# Brain - Nucleus accumbens (basal ganglia)
# Brain - Putamen (basal ganglia)
# Brain - Spinal cord (cervical c-1)
# Brain - Substantia nigra
# Breast - Mammary Tissue
# Cells - EBV-transformed lymphocytes
# Cells - Transformed fibroblasts
# Colon - Sigmoid
# Colon - Transverse
# Esophagus - Gastroesophageal Junction
# Esophagus - Mucosa
# Esophagus - Muscularis
# Heart - Atrial Appendage
# Heart - Left Ventricle
# Liver
# Lung
# Minor Salivary Gland
# Muscle - Skeletal
# Nerve - Tibial
# Ovary
# Pancreas
# Pituitary
# Prostate
# Skin - Not Sun Exposed (Suprapubic)
# Skin - Sun Exposed (Lower leg)
# Small Intestine - Terminal Ileum
# Spleen
# Stomach
# Testis
# Thyroid
# Uterus
# Vagina
# Whole Blood

# %%
allTissuesCombined_ohnologs_metasoft
# Out:
#        Ensembl Gene ID       type    field   SNPs  eQTLs  propSignif  \
# 0      ENSG00000138593       ohno  gene_id   5645   16.0    0.002834
# 1      ENSG00000168675        SSD  gene_id   7911    0.0    0.000000
# 2      ENSG00000188992        SSD  gene_id   8607  248.0    0.028814
# 3      ENSG00000185272       ohno  gene_id   8622  111.0    0.012874
# 4      ENSG00000155304  singleton  gene_id   8566   26.0    0.003035
# 5      ENSG00000166200        SSD  gene_id   5891   30.0    0.005093
# 6      ENSG00000155307        SSD  gene_id   8545    0.0    0.000000
# 7      ENSG00000153575        SSD  gene_id   4601  130.0    0.028255
# 8      ENSG00000180530  singleton  gene_id   8460    0.0    0.000000
# 9      ENSG00000137824       ohno  gene_id   5804  141.0    0.024294
# 10     ENSG00000259458  singleton  gene_id   7516    0.0    0.000000
# 11     ENSG00000137880  singleton  gene_id   5790    0.0    0.000000
# 12     ENSG00000104129        SSD  gene_id   5741  295.0    0.051385
# 13     ENSG00000177150        SSD  gene_id   8431   98.0    0.011624
# 14     ENSG00000155313       ohno  gene_id   7272    3.0    0.000413
# 15     ENSG00000101638        SSD  gene_id   7134  145.0    0.020325
# 16     ENSG00000154639        SSD  gene_id   8762    1.0    0.000114
# 17     ENSG00000101654  singleton  gene_id   8431   67.0    0.007947
# 18     ENSG00000078043       ohno  gene_id   7044  334.0    0.047416
# 19     ENSG00000156958        SSD  gene_id   5891   10.0    0.001698
# 20     ENSG00000154640        SSD  gene_id   8876    4.0    0.000451
# 21     ENSG00000140416       ohno  gene_id   7646  198.0    0.025896
# 22     ENSG00000154642  singleton  gene_id   9175    0.0    0.000000
# 23     ENSG00000140577       ohno  gene_id   8399  100.0    0.011906
# 24     ENSG00000166140  singleton  gene_id   5723  727.0    0.127031
# 25     ENSG00000101138        SSD  gene_id   8863   90.0    0.010155
# 26     ENSG00000154645        SSD  gene_id   9301   25.0    0.002688
# 27     ENSG00000068793        SSD  gene_id   4852  107.0    0.022053
# 28     ENSG00000182931  singleton  gene_id   6706   14.0    0.002088
# 29     ENSG00000101365        SSD  gene_id   8212   95.0    0.011568
# ...                ...        ...      ...    ...    ...         ...
# 14804  ENSG00000105507       ohno  gene_id   8218    0.0    0.000000
# 14805  ENSG00000187475        SSD  gene_id   7753    0.0    0.000000
# 14806  ENSG00000268000  singleton  gene_id   8139    0.0    0.000000
# 14807  ENSG00000181616        SSD  gene_id  11284    0.0    0.000000
# 14808  ENSG00000185990        SSD  gene_id   2336    0.0    0.000000
# 14809  ENSG00000182393        SSD  gene_id   7281    0.0    0.000000
# 14810  ENSG00000254019  singleton  gene_id   7995    0.0    0.000000
# 14811  ENSG00000175779  singleton  gene_id   7972    0.0    0.000000
# 14812  ENSG00000175485  singleton  gene_id  10350    0.0    0.000000
# 14813  ENSG00000184321        SSD  gene_id  11982    0.0    0.000000
# 14814  ENSG00000156575        SSD  gene_id   7207    0.0    0.000000
# 14815  ENSG00000221937        SSD  gene_id   5344    0.0    0.000000
# 14816  ENSG00000105370  singleton  gene_id   9585    0.0    0.000000
# 14817  ENSG00000182572        SSD  gene_id   7191    0.0    0.000000
# 14818  ENSG00000240247        SSD  gene_id   9793    0.0    0.000000
# 14819  ENSG00000176922  singleton  gene_id  11980    0.0    0.000000
# 14820  ENSG00000249160  singleton  gene_id   8492    0.0    0.000000
# 14821  ENSG00000167359        SSD  gene_id  11815    0.0    0.000000
# 14822  ENSG00000184881        SSD  gene_id  12070    0.0    0.000000
# 14823  ENSG00000255307        SSD  gene_id  10601    0.0    0.000000
# 14824  ENSG00000171987  singleton  gene_id  11519    0.0    0.000000
# 14825  ENSG00000205300  singleton  gene_id   8719    0.0    0.000000
# 14826  ENSG00000221996        SSD  gene_id  11514    0.0    0.000000
# 14827  ENSG00000197790        SSD  gene_id  11539    0.0    0.000000
# 14828  ENSG00000184698        SSD  gene_id  12039    0.0    0.000000
# 14829  ENSG00000269468  singleton  gene_id   7527    0.0    0.000000
# 14830  ENSG00000206047        SSD  gene_id  10043    0.0    0.000000
# 14831  ENSG00000176239        SSD  gene_id  12059    0.0    0.000000
# 14832  ENSG00000182070        SSD  gene_id  12441    0.0    0.000000
# 14833  ENSG00000176893        SSD  gene_id  12167    0.0    0.000000
#
#                        tissue
# 0      Adipose - Subcutaneous
# 1      Adipose - Subcutaneous
# 2      Adipose - Subcutaneous
# 3      Adipose - Subcutaneous
# 4      Adipose - Subcutaneous
# 5      Adipose - Subcutaneous
# 6      Adipose - Subcutaneous
# 7      Adipose - Subcutaneous
# 8      Adipose - Subcutaneous
# 9      Adipose - Subcutaneous
# 10     Adipose - Subcutaneous
# 11     Adipose - Subcutaneous
# 12     Adipose - Subcutaneous
# 13     Adipose - Subcutaneous
# 14     Adipose - Subcutaneous
# 15     Adipose - Subcutaneous
# 16     Adipose - Subcutaneous
# 17     Adipose - Subcutaneous
# 18     Adipose - Subcutaneous
# 19     Adipose - Subcutaneous
# 20     Adipose - Subcutaneous
# 21     Adipose - Subcutaneous
# 22     Adipose - Subcutaneous
# 23     Adipose - Subcutaneous
# 24     Adipose - Subcutaneous
# 25     Adipose - Subcutaneous
# 26     Adipose - Subcutaneous
# 27     Adipose - Subcutaneous
# 28     Adipose - Subcutaneous
# 29     Adipose - Subcutaneous
# ...                       ...
# 14804             Whole Blood
# 14805             Whole Blood
# 14806             Whole Blood
# 14807             Whole Blood
# 14808             Whole Blood
# 14809             Whole Blood
# 14810             Whole Blood
# 14811             Whole Blood
# 14812             Whole Blood
# 14813             Whole Blood
# 14814             Whole Blood
# 14815             Whole Blood
# 14816             Whole Blood
# 14817             Whole Blood
# 14818             Whole Blood
# 14819             Whole Blood
# 14820             Whole Blood
# 14821             Whole Blood
# 14822             Whole Blood
# 14823             Whole Blood
# 14824             Whole Blood
# 14825             Whole Blood
# 14826             Whole Blood
# 14827             Whole Blood
# 14828             Whole Blood
# 14829             Whole Blood
# 14830             Whole Blood
# 14831             Whole Blood
# 14832             Whole Blood
# 14833             Whole Blood
#
# [790141 rows x 7 columns]

# %%
allTissuesCombined_ohnologs_metasoft.describe()
# Out:
#                 SNPs          eQTLs     propSignif
# count  790141.000000  790141.000000  790141.000000
# mean     7199.385029     102.445062       0.014918
# std      2238.421046     266.765389       0.033716
# min       119.000000       0.000000       0.000000
# 25%      6104.000000       0.000000       0.000000
# 50%      7160.000000      13.000000       0.001810
# 75%      8125.000000     107.000000       0.015180
# max     28260.000000    8955.000000       0.653515

# %%
allTissuesCombined_ohnologs_metasoft.to_csv('../../outputFiles/propSNPsSignificanteQTLsOhnologsMetasoft.csv', index=False)

# %% [markdown]
# #### CNVRs (Zarrei et al.)

# %% [markdown]
# ##### Bonferroni-corrected eQTLs

# %%
allTissuesCombined_CNVZarrei_bonferroni = pd.DataFrame()
for tissue in tissues:
    print(tissue)
    tissue_url = tissue.replace(' - ','_').replace('(','').replace(')','').replace(' ','_')
    eQTLCountPerGeneBonferroni = pd.read_sql_query(
        'SELECT gene_id as "Ensembl Gene ID", COUNT(*) as eQTLs FROM `v7` WHERE sigAfterBonferroni = 1 AND tissue = "' + tissue + '" GROUP BY gene_id',
        engine,
        coerce_float=True
    )
    numTestedSNPs = pd.read_csv('../../outputFiles/GTExV7/numTestedSNPs/' + tissue + '.txt')
    numTestedSNPs.rename(columns={'value': 'Ensembl Gene ID', 'count': 'SNPs'}, inplace=True)
    genesWitheQTLTissueCountBonferroniAndCNVZarreiStatus = pd.read_csv('../../outputFiles/genesWitheQTLTissueCountBonferroniAndCNVZarreiStatus.csv', sep="\t", index_col="Unnamed: 0")
    
    numTestedSNPs["Ensembl Gene ID"] = numTestedSNPs["Ensembl Gene ID"].apply(removeGeneIDVersions)
    eQTLCountPerGeneBonferroni["Ensembl Gene ID"] = eQTLCountPerGeneBonferroni["Ensembl Gene ID"].apply(removeGeneIDVersions)
    
    merge1 = pd.merge(genesWitheQTLTissueCountBonferroniAndCNVZarreiStatus[['Ensembl Gene ID','CNV']], numTestedSNPs, how = "inner", on = "Ensembl Gene ID")
    merge2 = pd.merge(merge1, eQTLCountPerGeneBonferroni, how = "left", on = "Ensembl Gene ID")
    merge2['eQTLs'] = merge2['eQTLs'].fillna(0)
    
    merge2['propSignif'] = merge2['eQTLs']/merge2['SNPs']
    merge2['tissue'] = tissue
    allTissuesCombined_CNVZarrei_bonferroni = allTissuesCombined_CNVZarrei_bonferroni.append(merge2)
# Out:
# Adipose - Subcutaneous
# Adipose - Visceral (Omentum)
# Adrenal Gland
# Artery - Aorta
# Artery - Coronary
# Artery - Tibial
# Brain - Amygdala
# Brain - Anterior cingulate cortex (BA24)
# Brain - Caudate (basal ganglia)
# Brain - Cerebellar Hemisphere
# Brain - Cerebellum
# Brain - Cortex
# Brain - Frontal Cortex (BA9)
# Brain - Hippocampus
# Brain - Hypothalamus
# Brain - Nucleus accumbens (basal ganglia)
# Brain - Putamen (basal ganglia)
# Brain - Spinal cord (cervical c-1)
# Brain - Substantia nigra
# Breast - Mammary Tissue
# Cells - EBV-transformed lymphocytes
# Cells - Transformed fibroblasts
# Colon - Sigmoid
# Colon - Transverse
# Esophagus - Gastroesophageal Junction
# Esophagus - Mucosa
# Esophagus - Muscularis
# Heart - Atrial Appendage
# Heart - Left Ventricle
# Liver
# Lung
# Minor Salivary Gland
# Muscle - Skeletal
# Nerve - Tibial
# Ovary
# Pancreas
# Pituitary
# Prostate
# Skin - Not Sun Exposed (Suprapubic)
# Skin - Sun Exposed (Lower leg)
# Small Intestine - Terminal Ileum
# Spleen
# Stomach
# Testis
# Thyroid
# Uterus
# Vagina
# Whole Blood

# %%
allTissuesCombined_CNVZarrei_bonferroni
# Out:
#        Ensembl Gene ID CNV    field   SNPs  eQTLs  propSignif  \
# 0      ENSG00000138593   N  gene_id   5645    0.0    0.000000
# 1      ENSG00000168675   Y  gene_id   7911    0.0    0.000000
# 2      ENSG00000188992   N  gene_id   8607    0.0    0.000000
# 3      ENSG00000185272   N  gene_id   8622    0.0    0.000000
# 4      ENSG00000155304   N  gene_id   8566    0.0    0.000000
# 5      ENSG00000153575   Y  gene_id   4601   89.0    0.019344
# 6      ENSG00000180530   Y  gene_id   8460    0.0    0.000000
# 7      ENSG00000137824   N  gene_id   5804   25.0    0.004307
# 8      ENSG00000137880   N  gene_id   5790    0.0    0.000000
# 9      ENSG00000104129   N  gene_id   5741    1.0    0.000174
# 10     ENSG00000177150   Y  gene_id   8431    0.0    0.000000
# 11     ENSG00000155313   N  gene_id   7272    0.0    0.000000
# 12     ENSG00000101638   Y  gene_id   7134    0.0    0.000000
# 13     ENSG00000154639   Y  gene_id   8762    0.0    0.000000
# 14     ENSG00000101654   N  gene_id   8431    0.0    0.000000
# 15     ENSG00000078043   Y  gene_id   7044   15.0    0.002129
# 16     ENSG00000156958   Y  gene_id   5891    0.0    0.000000
# 17     ENSG00000154640   Y  gene_id   8876    0.0    0.000000
# 18     ENSG00000140416   N  gene_id   7646   79.0    0.010332
# 19     ENSG00000154642   N  gene_id   9175    0.0    0.000000
# 20     ENSG00000140577   Y  gene_id   8399    2.0    0.000238
# 21     ENSG00000166140   N  gene_id   5723  433.0    0.075660
# 22     ENSG00000101138   N  gene_id   8863    4.0    0.000451
# 23     ENSG00000154645   Y  gene_id   9301    0.0    0.000000
# 24     ENSG00000068793   Y  gene_id   4852   34.0    0.007007
# 25     ENSG00000182931   N  gene_id   6706    0.0    0.000000
# 26     ENSG00000101365   N  gene_id   8212    0.0    0.000000
# 27     ENSG00000167216   Y  gene_id   7041  323.0    0.045874
# 28     ENSG00000124116   Y  gene_id   6832  671.0    0.098214
# 29     ENSG00000087589   Y  gene_id   8902    0.0    0.000000
# ...                ...  ..      ...    ...    ...         ...
# 14804  ENSG00000187475   N  gene_id   7753    0.0    0.000000
# 14805  ENSG00000268000   N  gene_id   8139    0.0    0.000000
# 14806  ENSG00000181616   N  gene_id  11284    0.0    0.000000
# 14807  ENSG00000185990   N  gene_id   2336    0.0    0.000000
# 14808  ENSG00000182393   N  gene_id   7281    0.0    0.000000
# 14809  ENSG00000254019   N  gene_id   7995    0.0    0.000000
# 14810  ENSG00000175779   N  gene_id   7972    0.0    0.000000
# 14811  ENSG00000175485   N  gene_id  10350    0.0    0.000000
# 14812  ENSG00000184321   N  gene_id  11982    0.0    0.000000
# 14813  ENSG00000156575   N  gene_id   7207    0.0    0.000000
# 14814  ENSG00000221937   N  gene_id   5344    0.0    0.000000
# 14815  ENSG00000105370   N  gene_id   9585    0.0    0.000000
# 14816  ENSG00000182572   N  gene_id   7191    0.0    0.000000
# 14817  ENSG00000176895   N  gene_id  12141    0.0    0.000000
# 14818  ENSG00000240247   Y  gene_id   9793    0.0    0.000000
# 14819  ENSG00000187918   N  gene_id  11780    0.0    0.000000
# 14820  ENSG00000176922   N  gene_id  11980    0.0    0.000000
# 14821  ENSG00000249160   Y  gene_id   8492    0.0    0.000000
# 14822  ENSG00000167359   N  gene_id  11815    0.0    0.000000
# 14823  ENSG00000184881   N  gene_id  12070    0.0    0.000000
# 14824  ENSG00000255307   Y  gene_id  10601    0.0    0.000000
# 14825  ENSG00000171987   N  gene_id  11519    0.0    0.000000
# 14826  ENSG00000205300   Y  gene_id   8719    0.0    0.000000
# 14827  ENSG00000221996   N  gene_id  11514    0.0    0.000000
# 14828  ENSG00000197790   N  gene_id  11539    0.0    0.000000
# 14829  ENSG00000184698   Y  gene_id  12039    0.0    0.000000
# 14830  ENSG00000206047   Y  gene_id  10043    0.0    0.000000
# 14831  ENSG00000176239   Y  gene_id  12059    0.0    0.000000
# 14832  ENSG00000182070   N  gene_id  12441    0.0    0.000000
# 14833  ENSG00000176893   N  gene_id  12167    0.0    0.000000
#
#                        tissue
# 0      Adipose - Subcutaneous
# 1      Adipose - Subcutaneous
# 2      Adipose - Subcutaneous
# 3      Adipose - Subcutaneous
# 4      Adipose - Subcutaneous
# 5      Adipose - Subcutaneous
# 6      Adipose - Subcutaneous
# 7      Adipose - Subcutaneous
# 8      Adipose - Subcutaneous
# 9      Adipose - Subcutaneous
# 10     Adipose - Subcutaneous
# 11     Adipose - Subcutaneous
# 12     Adipose - Subcutaneous
# 13     Adipose - Subcutaneous
# 14     Adipose - Subcutaneous
# 15     Adipose - Subcutaneous
# 16     Adipose - Subcutaneous
# 17     Adipose - Subcutaneous
# 18     Adipose - Subcutaneous
# 19     Adipose - Subcutaneous
# 20     Adipose - Subcutaneous
# 21     Adipose - Subcutaneous
# 22     Adipose - Subcutaneous
# 23     Adipose - Subcutaneous
# 24     Adipose - Subcutaneous
# 25     Adipose - Subcutaneous
# 26     Adipose - Subcutaneous
# 27     Adipose - Subcutaneous
# 28     Adipose - Subcutaneous
# 29     Adipose - Subcutaneous
# ...                       ...
# 14804             Whole Blood
# 14805             Whole Blood
# 14806             Whole Blood
# 14807             Whole Blood
# 14808             Whole Blood
# 14809             Whole Blood
# 14810             Whole Blood
# 14811             Whole Blood
# 14812             Whole Blood
# 14813             Whole Blood
# 14814             Whole Blood
# 14815             Whole Blood
# 14816             Whole Blood
# 14817             Whole Blood
# 14818             Whole Blood
# 14819             Whole Blood
# 14820             Whole Blood
# 14821             Whole Blood
# 14822             Whole Blood
# 14823             Whole Blood
# 14824             Whole Blood
# 14825             Whole Blood
# 14826             Whole Blood
# 14827             Whole Blood
# 14828             Whole Blood
# 14829             Whole Blood
# 14830             Whole Blood
# 14831             Whole Blood
# 14832             Whole Blood
# 14833             Whole Blood
#
# [790141 rows x 7 columns]

# %%
allTissuesCombined_CNVZarrei_bonferroni.describe()
# Out:
#                 SNPs          eQTLs     propSignif
# count  790141.000000  790141.000000  790141.000000
# mean     7199.385029      17.646458       0.002585
# std      2238.421046      90.743363       0.012777
# min       119.000000       0.000000       0.000000
# 25%      6104.000000       0.000000       0.000000
# 50%      7160.000000       0.000000       0.000000
# 75%      8125.000000       0.000000       0.000000
# max     28260.000000    4540.000000       0.524256

# %%
allTissuesCombined_CNVZarrei_bonferroni.to_csv('../../outputFiles/propSNPsSignificanteQTLsCNVZarreiBonferroni.csv', index=False)

# %% [markdown]
# ##### Metasoft eQTLs

# %%
allTissuesCombined_CNVZarrei_metasoft = pd.DataFrame()
for tissue in tissues:
    print(tissue)
    tissue_url = tissue.replace(' - ','_').replace('(','').replace(')','').replace(' ','_')
    eQTLCountPerGeneMetasoft = pd.read_sql_query(
        'SELECT gene as "Ensembl Gene ID", COUNT(*) as eQTLs FROM `v7Metasoft` WHERE `mval_' + tissue_url + '` > 0.9 GROUP BY gene',
        engine,
        coerce_float=True
    )
    numTestedSNPs = pd.read_csv('../../outputFiles/GTExV7/numTestedSNPs/' + tissue + '.txt')
    numTestedSNPs.rename(columns={'value': 'Ensembl Gene ID', 'count': 'SNPs'}, inplace=True)
    genesWitheQTLTissueCountMetasoftAndCNVZarreiStatus = pd.read_csv('../../outputFiles/genesWitheQTLTissueCountMetasoftAndCNVZarreiStatus.csv', sep="\t", index_col="Unnamed: 0")
    
    numTestedSNPs["Ensembl Gene ID"] = numTestedSNPs["Ensembl Gene ID"].apply(removeGeneIDVersions)
    eQTLCountPerGeneMetasoft["Ensembl Gene ID"] = eQTLCountPerGeneMetasoft["Ensembl Gene ID"].apply(removeGeneIDVersions)
    
    merge1 = pd.merge(genesWitheQTLTissueCountMetasoftAndCNVZarreiStatus[['Ensembl Gene ID','CNV']], numTestedSNPs, how = "inner", on = "Ensembl Gene ID")
    merge2 = pd.merge(merge1, eQTLCountPerGeneMetasoft, how = "left", on = "Ensembl Gene ID")
    merge2['eQTLs'] = merge2['eQTLs'].fillna(0)
    
    merge2['propSignif'] = merge2['eQTLs']/merge2['SNPs']
    merge2['tissue'] = tissue
    allTissuesCombined_CNVZarrei_metasoft = allTissuesCombined_CNVZarrei_metasoft.append(merge2)
# Out:
# Adipose - Subcutaneous
# Adipose - Visceral (Omentum)
# Adrenal Gland
# Artery - Aorta
# Artery - Coronary
# Artery - Tibial
# Brain - Amygdala
# Brain - Anterior cingulate cortex (BA24)
# Brain - Caudate (basal ganglia)
# Brain - Cerebellar Hemisphere
# Brain - Cerebellum
# Brain - Cortex
# Brain - Frontal Cortex (BA9)
# Brain - Hippocampus
# Brain - Hypothalamus
# Brain - Nucleus accumbens (basal ganglia)
# Brain - Putamen (basal ganglia)
# Brain - Spinal cord (cervical c-1)
# Brain - Substantia nigra
# Breast - Mammary Tissue
# Cells - EBV-transformed lymphocytes
# Cells - Transformed fibroblasts
# Colon - Sigmoid
# Colon - Transverse
# Esophagus - Gastroesophageal Junction
# Esophagus - Mucosa
# Esophagus - Muscularis
# Heart - Atrial Appendage
# Heart - Left Ventricle
# Liver
# Lung
# Minor Salivary Gland
# Muscle - Skeletal
# Nerve - Tibial
# Ovary
# Pancreas
# Pituitary
# Prostate
# Skin - Not Sun Exposed (Suprapubic)
# Skin - Sun Exposed (Lower leg)
# Small Intestine - Terminal Ileum
# Spleen
# Stomach
# Testis
# Thyroid
# Uterus
# Vagina
# Whole Blood

# %%
allTissuesCombined_CNVZarrei_metasoft
# Out:
#        Ensembl Gene ID CNV    field   SNPs  eQTLs  propSignif  \
# 0      ENSG00000138593   N  gene_id   5645   16.0    0.002834
# 1      ENSG00000168675   Y  gene_id   7911    0.0    0.000000
# 2      ENSG00000188992   N  gene_id   8607  248.0    0.028814
# 3      ENSG00000185272   N  gene_id   8622  111.0    0.012874
# 4      ENSG00000155304   N  gene_id   8566   26.0    0.003035
# 5      ENSG00000166200   N  gene_id   5891   30.0    0.005093
# 6      ENSG00000155307   N  gene_id   8545    0.0    0.000000
# 7      ENSG00000153575   Y  gene_id   4601  130.0    0.028255
# 8      ENSG00000180530   Y  gene_id   8460    0.0    0.000000
# 9      ENSG00000137824   N  gene_id   5804  141.0    0.024294
# 10     ENSG00000259458   N  gene_id   7516    0.0    0.000000
# 11     ENSG00000137880   N  gene_id   5790    0.0    0.000000
# 12     ENSG00000104129   N  gene_id   5741  295.0    0.051385
# 13     ENSG00000177150   Y  gene_id   8431   98.0    0.011624
# 14     ENSG00000155313   N  gene_id   7272    3.0    0.000413
# 15     ENSG00000101638   Y  gene_id   7134  145.0    0.020325
# 16     ENSG00000154639   Y  gene_id   8762    1.0    0.000114
# 17     ENSG00000101654   N  gene_id   8431   67.0    0.007947
# 18     ENSG00000078043   Y  gene_id   7044  334.0    0.047416
# 19     ENSG00000156958   Y  gene_id   5891   10.0    0.001698
# 20     ENSG00000154640   Y  gene_id   8876    4.0    0.000451
# 21     ENSG00000140416   N  gene_id   7646  198.0    0.025896
# 22     ENSG00000154642   N  gene_id   9175    0.0    0.000000
# 23     ENSG00000140577   Y  gene_id   8399  100.0    0.011906
# 24     ENSG00000166140   N  gene_id   5723  727.0    0.127031
# 25     ENSG00000101138   N  gene_id   8863   90.0    0.010155
# 26     ENSG00000154645   Y  gene_id   9301   25.0    0.002688
# 27     ENSG00000068793   Y  gene_id   4852  107.0    0.022053
# 28     ENSG00000182931   N  gene_id   6706   14.0    0.002088
# 29     ENSG00000101365   N  gene_id   8212   95.0    0.011568
# ...                ...  ..      ...    ...    ...         ...
# 14804  ENSG00000105507   N  gene_id   8218    0.0    0.000000
# 14805  ENSG00000187475   N  gene_id   7753    0.0    0.000000
# 14806  ENSG00000268000   N  gene_id   8139    0.0    0.000000
# 14807  ENSG00000181616   N  gene_id  11284    0.0    0.000000
# 14808  ENSG00000185990   N  gene_id   2336    0.0    0.000000
# 14809  ENSG00000182393   N  gene_id   7281    0.0    0.000000
# 14810  ENSG00000254019   N  gene_id   7995    0.0    0.000000
# 14811  ENSG00000175779   N  gene_id   7972    0.0    0.000000
# 14812  ENSG00000175485   N  gene_id  10350    0.0    0.000000
# 14813  ENSG00000184321   N  gene_id  11982    0.0    0.000000
# 14814  ENSG00000156575   N  gene_id   7207    0.0    0.000000
# 14815  ENSG00000221937   N  gene_id   5344    0.0    0.000000
# 14816  ENSG00000105370   N  gene_id   9585    0.0    0.000000
# 14817  ENSG00000182572   N  gene_id   7191    0.0    0.000000
# 14818  ENSG00000240247   Y  gene_id   9793    0.0    0.000000
# 14819  ENSG00000176922   N  gene_id  11980    0.0    0.000000
# 14820  ENSG00000249160   Y  gene_id   8492    0.0    0.000000
# 14821  ENSG00000167359   N  gene_id  11815    0.0    0.000000
# 14822  ENSG00000184881   N  gene_id  12070    0.0    0.000000
# 14823  ENSG00000255307   Y  gene_id  10601    0.0    0.000000
# 14824  ENSG00000171987   N  gene_id  11519    0.0    0.000000
# 14825  ENSG00000205300   Y  gene_id   8719    0.0    0.000000
# 14826  ENSG00000221996   N  gene_id  11514    0.0    0.000000
# 14827  ENSG00000197790   N  gene_id  11539    0.0    0.000000
# 14828  ENSG00000184698   Y  gene_id  12039    0.0    0.000000
# 14829  ENSG00000269468   Y  gene_id   7527    0.0    0.000000
# 14830  ENSG00000206047   Y  gene_id  10043    0.0    0.000000
# 14831  ENSG00000176239   Y  gene_id  12059    0.0    0.000000
# 14832  ENSG00000182070   N  gene_id  12441    0.0    0.000000
# 14833  ENSG00000176893   N  gene_id  12167    0.0    0.000000
#
#                        tissue
# 0      Adipose - Subcutaneous
# 1      Adipose - Subcutaneous
# 2      Adipose - Subcutaneous
# 3      Adipose - Subcutaneous
# 4      Adipose - Subcutaneous
# 5      Adipose - Subcutaneous
# 6      Adipose - Subcutaneous
# 7      Adipose - Subcutaneous
# 8      Adipose - Subcutaneous
# 9      Adipose - Subcutaneous
# 10     Adipose - Subcutaneous
# 11     Adipose - Subcutaneous
# 12     Adipose - Subcutaneous
# 13     Adipose - Subcutaneous
# 14     Adipose - Subcutaneous
# 15     Adipose - Subcutaneous
# 16     Adipose - Subcutaneous
# 17     Adipose - Subcutaneous
# 18     Adipose - Subcutaneous
# 19     Adipose - Subcutaneous
# 20     Adipose - Subcutaneous
# 21     Adipose - Subcutaneous
# 22     Adipose - Subcutaneous
# 23     Adipose - Subcutaneous
# 24     Adipose - Subcutaneous
# 25     Adipose - Subcutaneous
# 26     Adipose - Subcutaneous
# 27     Adipose - Subcutaneous
# 28     Adipose - Subcutaneous
# 29     Adipose - Subcutaneous
# ...                       ...
# 14804             Whole Blood
# 14805             Whole Blood
# 14806             Whole Blood
# 14807             Whole Blood
# 14808             Whole Blood
# 14809             Whole Blood
# 14810             Whole Blood
# 14811             Whole Blood
# 14812             Whole Blood
# 14813             Whole Blood
# 14814             Whole Blood
# 14815             Whole Blood
# 14816             Whole Blood
# 14817             Whole Blood
# 14818             Whole Blood
# 14819             Whole Blood
# 14820             Whole Blood
# 14821             Whole Blood
# 14822             Whole Blood
# 14823             Whole Blood
# 14824             Whole Blood
# 14825             Whole Blood
# 14826             Whole Blood
# 14827             Whole Blood
# 14828             Whole Blood
# 14829             Whole Blood
# 14830             Whole Blood
# 14831             Whole Blood
# 14832             Whole Blood
# 14833             Whole Blood
#
# [790141 rows x 7 columns]

# %%
allTissuesCombined_CNVZarrei_metasoft.describe()
# Out:
#                 SNPs          eQTLs     propSignif
# count  790141.000000  790141.000000  790141.000000
# mean     7199.385029     102.445062       0.014918
# std      2238.421046     266.765389       0.033716
# min       119.000000       0.000000       0.000000
# 25%      6104.000000       0.000000       0.000000
# 50%      7160.000000      13.000000       0.001810
# 75%      8125.000000     107.000000       0.015180
# max     28260.000000    8955.000000       0.653515

# %%
allTissuesCombined_CNVZarrei_metasoft.to_csv('../../outputFiles/propSNPsSignificanteQTLsCNVZarreiMetasoft.csv', index=False)

# %% [markdown]
# #### CNVs (ExAC data)

# %% [markdown]
# ##### Bonferroni-corrected eQTLs

# %%
allTissuesCombined_CNVExAC_bonferroni = pd.DataFrame()
for tissue in tissues:
    print(tissue)
    tissue_url = tissue.replace(' - ','_').replace('(','').replace(')','').replace(' ','_')
    eQTLCountPerGeneBonferroni = pd.read_sql_query(
        'SELECT gene_id as "Ensembl Gene ID", COUNT(*) as eQTLs FROM `v7` WHERE sigAfterBonferroni = 1 AND tissue = "' + tissue + '" GROUP BY gene_id',
        engine,
        coerce_float=True
    )
    numTestedSNPs = pd.read_csv('../../outputFiles/GTExV7/numTestedSNPs/' + tissue + '.txt')
    numTestedSNPs.rename(columns={'value': 'Ensembl Gene ID', 'count': 'SNPs'}, inplace=True)
    genesWitheQTLTissueCountBonferroniAndCNVExACStatus = pd.read_csv('../../outputFiles/genesWitheQTLTissueCountBonferroniAndCNVExACStatus.csv', sep="\t", index_col="Unnamed: 0")
    
    numTestedSNPs["Ensembl Gene ID"] = numTestedSNPs["Ensembl Gene ID"].apply(removeGeneIDVersions)
    eQTLCountPerGeneBonferroni["Ensembl Gene ID"] = eQTLCountPerGeneBonferroni["Ensembl Gene ID"].apply(removeGeneIDVersions)
    
    merge1 = pd.merge(genesWitheQTLTissueCountBonferroniAndCNVExACStatus[['Ensembl Gene ID','CNV']], numTestedSNPs, how = "inner", on = "Ensembl Gene ID")
    merge2 = pd.merge(merge1, eQTLCountPerGeneBonferroni, how = "left", on = "Ensembl Gene ID")
    merge2['eQTLs'] = merge2['eQTLs'].fillna(0)
    
    merge2['propSignif'] = merge2['eQTLs']/merge2['SNPs']
    merge2['tissue'] = tissue
    allTissuesCombined_CNVExAC_bonferroni = allTissuesCombined_CNVExAC_bonferroni.append(merge2)
# Out:
# Adipose - Subcutaneous
# Adipose - Visceral (Omentum)
# Adrenal Gland
# Artery - Aorta
# Artery - Coronary
# Artery - Tibial
# Brain - Amygdala
# Brain - Anterior cingulate cortex (BA24)
# Brain - Caudate (basal ganglia)
# Brain - Cerebellar Hemisphere
# Brain - Cerebellum
# Brain - Cortex
# Brain - Frontal Cortex (BA9)
# Brain - Hippocampus
# Brain - Hypothalamus
# Brain - Nucleus accumbens (basal ganglia)
# Brain - Putamen (basal ganglia)
# Brain - Spinal cord (cervical c-1)
# Brain - Substantia nigra
# Breast - Mammary Tissue
# Cells - EBV-transformed lymphocytes
# Cells - Transformed fibroblasts
# Colon - Sigmoid
# Colon - Transverse
# Esophagus - Gastroesophageal Junction
# Esophagus - Mucosa
# Esophagus - Muscularis
# Heart - Atrial Appendage
# Heart - Left Ventricle
# Liver
# Lung
# Minor Salivary Gland
# Muscle - Skeletal
# Nerve - Tibial
# Ovary
# Pancreas
# Pituitary
# Prostate
# Skin - Not Sun Exposed (Suprapubic)
# Skin - Sun Exposed (Lower leg)
# Small Intestine - Terminal Ileum
# Spleen
# Stomach
# Testis
# Thyroid
# Uterus
# Vagina
# Whole Blood

# %%
allTissuesCombined_CNVExAC_bonferroni
# Out:
#        Ensembl Gene ID CNV    field   SNPs  eQTLs  propSignif  \
# 0      ENSG00000138593   N  gene_id   5645    0.0    0.000000
# 1      ENSG00000168675   Y  gene_id   7911    0.0    0.000000
# 2      ENSG00000185272   Y  gene_id   8622    0.0    0.000000
# 3      ENSG00000155304   Y  gene_id   8566    0.0    0.000000
# 4      ENSG00000180530   N  gene_id   8460    0.0    0.000000
# 5      ENSG00000137824   Y  gene_id   5804   25.0    0.004307
# 6      ENSG00000137880   Y  gene_id   5790    0.0    0.000000
# 7      ENSG00000104129   Y  gene_id   5741    1.0    0.000174
# 8      ENSG00000177150   Y  gene_id   8431    0.0    0.000000
# 9      ENSG00000155313   Y  gene_id   7272    0.0    0.000000
# 10     ENSG00000101638   Y  gene_id   7134    0.0    0.000000
# 11     ENSG00000154639   Y  gene_id   8762    0.0    0.000000
# 12     ENSG00000101654   Y  gene_id   8431    0.0    0.000000
# 13     ENSG00000078043   Y  gene_id   7044   15.0    0.002129
# 14     ENSG00000156958   Y  gene_id   5891    0.0    0.000000
# 15     ENSG00000154640   Y  gene_id   8876    0.0    0.000000
# 16     ENSG00000140416   Y  gene_id   7646   79.0    0.010332
# 17     ENSG00000154642   Y  gene_id   9175    0.0    0.000000
# 18     ENSG00000140577   Y  gene_id   8399    2.0    0.000238
# 19     ENSG00000166140   Y  gene_id   5723  433.0    0.075660
# 20     ENSG00000101138   N  gene_id   8863    4.0    0.000451
# 21     ENSG00000154645   Y  gene_id   9301    0.0    0.000000
# 22     ENSG00000182931   Y  gene_id   6706    0.0    0.000000
# 23     ENSG00000101365   Y  gene_id   8212    0.0    0.000000
# 24     ENSG00000124116   Y  gene_id   6832  671.0    0.098214
# 25     ENSG00000087589   Y  gene_id   8902    0.0    0.000000
# 26     ENSG00000154654   Y  gene_id   9483   62.0    0.006538
# 27     ENSG00000166262   Y  gene_id   6604   78.0    0.011811
# 28     ENSG00000103642   Y  gene_id   7580  202.0    0.026649
# 29     ENSG00000197299   Y  gene_id   8434    0.0    0.000000
# ...                ...  ..      ...    ...    ...         ...
# 12386  ENSG00000251606   Y  gene_id   8384    0.0    0.000000
# 12387  ENSG00000196532   Y  gene_id   7915    0.0    0.000000
# 12388  ENSG00000175520   Y  gene_id  11627    0.0    0.000000
# 12389  ENSG00000124196   Y  gene_id   6778    0.0    0.000000
# 12390  ENSG00000182611   Y  gene_id   6993    0.0    0.000000
# 12391  ENSG00000124529   Y  gene_id   7949    0.0    0.000000
# 12392  ENSG00000171136   Y  gene_id   7873    0.0    0.000000
# 12393  ENSG00000175514   Y  gene_id   6045    0.0    0.000000
# 12394  ENSG00000167360   Y  gene_id  11871    0.0    0.000000
# 12395  ENSG00000124693   Y  gene_id   7945    0.0    0.000000
# 12396  ENSG00000105507   Y  gene_id   8218    0.0    0.000000
# 12397  ENSG00000187475   Y  gene_id   7753    0.0    0.000000
# 12398  ENSG00000181616   Y  gene_id  11284    0.0    0.000000
# 12399  ENSG00000182393   Y  gene_id   7281    0.0    0.000000
# 12400  ENSG00000175779   N  gene_id   7972    0.0    0.000000
# 12401  ENSG00000175485   Y  gene_id  10350    0.0    0.000000
# 12402  ENSG00000156575   Y  gene_id   7207    0.0    0.000000
# 12403  ENSG00000105370   Y  gene_id   9585    0.0    0.000000
# 12404  ENSG00000182572   Y  gene_id   7191    0.0    0.000000
# 12405  ENSG00000176895   Y  gene_id  12141    0.0    0.000000
# 12406  ENSG00000187918   Y  gene_id  11780    0.0    0.000000
# 12407  ENSG00000176922   Y  gene_id  11980    0.0    0.000000
# 12408  ENSG00000167359   Y  gene_id  11815    0.0    0.000000
# 12409  ENSG00000184881   Y  gene_id  12070    0.0    0.000000
# 12410  ENSG00000255307   Y  gene_id  10601    0.0    0.000000
# 12411  ENSG00000221996   Y  gene_id  11514    0.0    0.000000
# 12412  ENSG00000197790   Y  gene_id  11539    0.0    0.000000
# 12413  ENSG00000184698   Y  gene_id  12039    0.0    0.000000
# 12414  ENSG00000176239   Y  gene_id  12059    0.0    0.000000
# 12415  ENSG00000182070   Y  gene_id  12441    0.0    0.000000
#
#                        tissue
# 0      Adipose - Subcutaneous
# 1      Adipose - Subcutaneous
# 2      Adipose - Subcutaneous
# 3      Adipose - Subcutaneous
# 4      Adipose - Subcutaneous
# 5      Adipose - Subcutaneous
# 6      Adipose - Subcutaneous
# 7      Adipose - Subcutaneous
# 8      Adipose - Subcutaneous
# 9      Adipose - Subcutaneous
# 10     Adipose - Subcutaneous
# 11     Adipose - Subcutaneous
# 12     Adipose - Subcutaneous
# 13     Adipose - Subcutaneous
# 14     Adipose - Subcutaneous
# 15     Adipose - Subcutaneous
# 16     Adipose - Subcutaneous
# 17     Adipose - Subcutaneous
# 18     Adipose - Subcutaneous
# 19     Adipose - Subcutaneous
# 20     Adipose - Subcutaneous
# 21     Adipose - Subcutaneous
# 22     Adipose - Subcutaneous
# 23     Adipose - Subcutaneous
# 24     Adipose - Subcutaneous
# 25     Adipose - Subcutaneous
# 26     Adipose - Subcutaneous
# 27     Adipose - Subcutaneous
# 28     Adipose - Subcutaneous
# 29     Adipose - Subcutaneous
# ...                       ...
# 12386             Whole Blood
# 12387             Whole Blood
# 12388             Whole Blood
# 12389             Whole Blood
# 12390             Whole Blood
# 12391             Whole Blood
# 12392             Whole Blood
# 12393             Whole Blood
# 12394             Whole Blood
# 12395             Whole Blood
# 12396             Whole Blood
# 12397             Whole Blood
# 12398             Whole Blood
# 12399             Whole Blood
# 12400             Whole Blood
# 12401             Whole Blood
# 12402             Whole Blood
# 12403             Whole Blood
# 12404             Whole Blood
# 12405             Whole Blood
# 12406             Whole Blood
# 12407             Whole Blood
# 12408             Whole Blood
# 12409             Whole Blood
# 12410             Whole Blood
# 12411             Whole Blood
# 12412             Whole Blood
# 12413             Whole Blood
# 12414             Whole Blood
# 12415             Whole Blood
#
# [651494 rows x 7 columns]

# %%
allTissuesCombined_CNVExAC_bonferroni.describe()
# Out:
#                 SNPs          eQTLs     propSignif
# count  651494.000000  651494.000000  651494.000000
# mean     7325.415852      15.831474       0.002309
# std      2079.277298      70.025695       0.010511
# min      1154.000000       0.000000       0.000000
# 25%      6270.000000       0.000000       0.000000
# 50%      7224.000000       0.000000       0.000000
# 75%      8125.000000       0.000000       0.000000
# max     28260.000000    3610.000000       0.524256

# %%
allTissuesCombined_CNVExAC_bonferroni.to_csv('../../outputFiles/propSNPsSignificanteQTLsCNVExACBonferroni.csv', index=False)

# %% [markdown]
# ##### Metasoft eQTLs

# %%
allTissuesCombined_CNVExAC_metasoft = pd.DataFrame()
for tissue in tissues:
    print(tissue)
    tissue_url = tissue.replace(' - ','_').replace('(','').replace(')','').replace(' ','_')
    eQTLCountPerGeneMetasoft = pd.read_sql_query(
        'SELECT gene as "Ensembl Gene ID", COUNT(*) as eQTLs FROM `v7Metasoft` WHERE `mval_' + tissue_url + '` > 0.9 GROUP BY gene',
        engine,
        coerce_float=True
    )
    numTestedSNPs = pd.read_csv('../../outputFiles/GTExV7/numTestedSNPs/' + tissue + '.txt')
    numTestedSNPs.rename(columns={'value': 'Ensembl Gene ID', 'count': 'SNPs'}, inplace=True)
    genesWitheQTLTissueCountMetasoftAndCNVExACStatus = pd.read_csv('../../outputFiles/genesWitheQTLTissueCountMetasoftAndCNVExACStatus.csv', sep="\t", index_col="Unnamed: 0")
    
    numTestedSNPs["Ensembl Gene ID"] = numTestedSNPs["Ensembl Gene ID"].apply(removeGeneIDVersions)
    eQTLCountPerGeneMetasoft["Ensembl Gene ID"] = eQTLCountPerGeneMetasoft["Ensembl Gene ID"].apply(removeGeneIDVersions)
    
    merge1 = pd.merge(genesWitheQTLTissueCountMetasoftAndCNVExACStatus[['Ensembl Gene ID','CNV']], numTestedSNPs, how = "inner", on = "Ensembl Gene ID")
    merge2 = pd.merge(merge1, eQTLCountPerGeneMetasoft, how = "left", on = "Ensembl Gene ID")
    merge2['eQTLs'] = merge2['eQTLs'].fillna(0)
    
    merge2['propSignif'] = merge2['eQTLs']/merge2['SNPs']
    merge2['tissue'] = tissue
    allTissuesCombined_CNVExAC_metasoft = allTissuesCombined_CNVExAC_metasoft.append(merge2)
# Out:
# Adipose - Subcutaneous
# Adipose - Visceral (Omentum)
# Adrenal Gland
# Artery - Aorta
# Artery - Coronary
# Artery - Tibial
# Brain - Amygdala
# Brain - Anterior cingulate cortex (BA24)
# Brain - Caudate (basal ganglia)
# Brain - Cerebellar Hemisphere
# Brain - Cerebellum
# Brain - Cortex
# Brain - Frontal Cortex (BA9)
# Brain - Hippocampus
# Brain - Hypothalamus
# Brain - Nucleus accumbens (basal ganglia)
# Brain - Putamen (basal ganglia)
# Brain - Spinal cord (cervical c-1)
# Brain - Substantia nigra
# Breast - Mammary Tissue
# Cells - EBV-transformed lymphocytes
# Cells - Transformed fibroblasts
# Colon - Sigmoid
# Colon - Transverse
# Esophagus - Gastroesophageal Junction
# Esophagus - Mucosa
# Esophagus - Muscularis
# Heart - Atrial Appendage
# Heart - Left Ventricle
# Liver
# Lung
# Minor Salivary Gland
# Muscle - Skeletal
# Nerve - Tibial
# Ovary
# Pancreas
# Pituitary
# Prostate
# Skin - Not Sun Exposed (Suprapubic)
# Skin - Sun Exposed (Lower leg)
# Small Intestine - Terminal Ileum
# Spleen
# Stomach
# Testis
# Thyroid
# Uterus
# Vagina
# Whole Blood

# %%
allTissuesCombined_CNVExAC_metasoft
# Out:
#        Ensembl Gene ID CNV    field   SNPs   eQTLs  propSignif  \
# 0      ENSG00000138593   N  gene_id   5645    16.0    0.002834
# 1      ENSG00000168675   Y  gene_id   7911     0.0    0.000000
# 2      ENSG00000185272   Y  gene_id   8622   111.0    0.012874
# 3      ENSG00000155304   Y  gene_id   8566    26.0    0.003035
# 4      ENSG00000166200   N  gene_id   5891    30.0    0.005093
# 5      ENSG00000155307   Y  gene_id   8545     0.0    0.000000
# 6      ENSG00000180530   N  gene_id   8460     0.0    0.000000
# 7      ENSG00000137824   Y  gene_id   5804   141.0    0.024294
# 8      ENSG00000137880   Y  gene_id   5790     0.0    0.000000
# 9      ENSG00000104129   Y  gene_id   5741   295.0    0.051385
# 10     ENSG00000177150   Y  gene_id   8431    98.0    0.011624
# 11     ENSG00000155313   Y  gene_id   7272     3.0    0.000413
# 12     ENSG00000101638   Y  gene_id   7134   145.0    0.020325
# 13     ENSG00000154639   Y  gene_id   8762     1.0    0.000114
# 14     ENSG00000101654   Y  gene_id   8431    67.0    0.007947
# 15     ENSG00000078043   Y  gene_id   7044   334.0    0.047416
# 16     ENSG00000156958   Y  gene_id   5891    10.0    0.001698
# 17     ENSG00000154640   Y  gene_id   8876     4.0    0.000451
# 18     ENSG00000140416   Y  gene_id   7646   198.0    0.025896
# 19     ENSG00000154642   Y  gene_id   9175     0.0    0.000000
# 20     ENSG00000140577   Y  gene_id   8399   100.0    0.011906
# 21     ENSG00000166140   Y  gene_id   5723   727.0    0.127031
# 22     ENSG00000101138   N  gene_id   8863    90.0    0.010155
# 23     ENSG00000154645   Y  gene_id   9301    25.0    0.002688
# 24     ENSG00000182931   Y  gene_id   6706    14.0    0.002088
# 25     ENSG00000101365   Y  gene_id   8212    95.0    0.011568
# 26     ENSG00000124116   Y  gene_id   6832  1257.0    0.183987
# 27     ENSG00000087589   Y  gene_id   8902    21.0    0.002359
# 28     ENSG00000154654   Y  gene_id   9483    83.0    0.008753
# 29     ENSG00000166262   Y  gene_id   6604   920.0    0.139310
# ...                ...  ..      ...    ...     ...         ...
# 12386  ENSG00000188987   Y  gene_id   7619     0.0    0.000000
# 12387  ENSG00000256018   Y  gene_id   7565     0.0    0.000000
# 12388  ENSG00000107447   Y  gene_id   6846     0.0    0.000000
# 12389  ENSG00000132703   Y  gene_id   8050     0.0    0.000000
# 12390  ENSG00000101323   Y  gene_id   8213     0.0    0.000000
# 12391  ENSG00000196532   Y  gene_id   7915     0.0    0.000000
# 12392  ENSG00000175520   Y  gene_id  11627     0.0    0.000000
# 12393  ENSG00000124196   Y  gene_id   6778     0.0    0.000000
# 12394  ENSG00000124529   Y  gene_id   7949     0.0    0.000000
# 12395  ENSG00000171136   Y  gene_id   7873     0.0    0.000000
# 12396  ENSG00000175514   Y  gene_id   6045     0.0    0.000000
# 12397  ENSG00000124693   Y  gene_id   7945     0.0    0.000000
# 12398  ENSG00000105507   Y  gene_id   8218     0.0    0.000000
# 12399  ENSG00000187475   Y  gene_id   7753     0.0    0.000000
# 12400  ENSG00000181616   Y  gene_id  11284     0.0    0.000000
# 12401  ENSG00000182393   Y  gene_id   7281     0.0    0.000000
# 12402  ENSG00000175779   N  gene_id   7972     0.0    0.000000
# 12403  ENSG00000175485   Y  gene_id  10350     0.0    0.000000
# 12404  ENSG00000156575   Y  gene_id   7207     0.0    0.000000
# 12405  ENSG00000105370   Y  gene_id   9585     0.0    0.000000
# 12406  ENSG00000182572   Y  gene_id   7191     0.0    0.000000
# 12407  ENSG00000176922   Y  gene_id  11980     0.0    0.000000
# 12408  ENSG00000167359   Y  gene_id  11815     0.0    0.000000
# 12409  ENSG00000184881   Y  gene_id  12070     0.0    0.000000
# 12410  ENSG00000255307   Y  gene_id  10601     0.0    0.000000
# 12411  ENSG00000221996   Y  gene_id  11514     0.0    0.000000
# 12412  ENSG00000197790   Y  gene_id  11539     0.0    0.000000
# 12413  ENSG00000184698   Y  gene_id  12039     0.0    0.000000
# 12414  ENSG00000176239   Y  gene_id  12059     0.0    0.000000
# 12415  ENSG00000182070   Y  gene_id  12441     0.0    0.000000
#
#                        tissue
# 0      Adipose - Subcutaneous
# 1      Adipose - Subcutaneous
# 2      Adipose - Subcutaneous
# 3      Adipose - Subcutaneous
# 4      Adipose - Subcutaneous
# 5      Adipose - Subcutaneous
# 6      Adipose - Subcutaneous
# 7      Adipose - Subcutaneous
# 8      Adipose - Subcutaneous
# 9      Adipose - Subcutaneous
# 10     Adipose - Subcutaneous
# 11     Adipose - Subcutaneous
# 12     Adipose - Subcutaneous
# 13     Adipose - Subcutaneous
# 14     Adipose - Subcutaneous
# 15     Adipose - Subcutaneous
# 16     Adipose - Subcutaneous
# 17     Adipose - Subcutaneous
# 18     Adipose - Subcutaneous
# 19     Adipose - Subcutaneous
# 20     Adipose - Subcutaneous
# 21     Adipose - Subcutaneous
# 22     Adipose - Subcutaneous
# 23     Adipose - Subcutaneous
# 24     Adipose - Subcutaneous
# 25     Adipose - Subcutaneous
# 26     Adipose - Subcutaneous
# 27     Adipose - Subcutaneous
# 28     Adipose - Subcutaneous
# 29     Adipose - Subcutaneous
# ...                       ...
# 12386             Whole Blood
# 12387             Whole Blood
# 12388             Whole Blood
# 12389             Whole Blood
# 12390             Whole Blood
# 12391             Whole Blood
# 12392             Whole Blood
# 12393             Whole Blood
# 12394             Whole Blood
# 12395             Whole Blood
# 12396             Whole Blood
# 12397             Whole Blood
# 12398             Whole Blood
# 12399             Whole Blood
# 12400             Whole Blood
# 12401             Whole Blood
# 12402             Whole Blood
# 12403             Whole Blood
# 12404             Whole Blood
# 12405             Whole Blood
# 12406             Whole Blood
# 12407             Whole Blood
# 12408             Whole Blood
# 12409             Whole Blood
# 12410             Whole Blood
# 12411             Whole Blood
# 12412             Whole Blood
# 12413             Whole Blood
# 12414             Whole Blood
# 12415             Whole Blood
#
# [651494 rows x 7 columns]

# %%
allTissuesCombined_CNVExAC_metasoft.describe()
# Out:
#                 SNPs          eQTLs     propSignif
# count  651494.000000  651494.000000  651494.000000
# mean     7325.415852      95.647765       0.013803
# std      2079.277298     215.870015       0.029745
# min      1154.000000       0.000000       0.000000
# 25%      6270.000000       0.000000       0.000000
# 50%      7224.000000      12.000000       0.001724
# 75%      8125.000000     104.000000       0.014501
# max     28260.000000    8955.000000       0.653515

# %%
allTissuesCombined_CNVExAC_metasoft.to_csv('../../outputFiles/propSNPsSignificanteQTLsCNVExACMetasoft.csv', index=False)

# %% [markdown]
# #### Haploinsufficient genes

# %% [markdown]
# ##### Bonferroni-corrected eQTLs

# %%
allTissuesCombined_Haplo_bonferroni = pd.DataFrame()
for tissue in tissues:
    print(tissue)
    tissue_url = tissue.replace(' - ','_').replace('(','').replace(')','').replace(' ','_')
    eQTLCountPerGeneBonferroni = pd.read_sql_query(
        'SELECT gene_id as "Ensembl Gene ID", COUNT(*) as eQTLs FROM `v7` WHERE sigAfterBonferroni = 1 AND tissue = "' + tissue + '" GROUP BY gene_id',
        engine,
        coerce_float=True
    )
    numTestedSNPs = pd.read_csv('../../outputFiles/GTExV7/numTestedSNPs/' + tissue + '.txt')
    numTestedSNPs.rename(columns={'value': 'Ensembl Gene ID', 'count': 'SNPs'}, inplace=True)
    genesWitheQTLTissueCountBonferroniAndHaploStatus = pd.read_csv('../../outputFiles/genesWitheQTLTissueCountBonferroniAndHaploStatus.csv', sep="\t", index_col="Unnamed: 0")
    
    numTestedSNPs["Ensembl Gene ID"] = numTestedSNPs["Ensembl Gene ID"].apply(removeGeneIDVersions)
    eQTLCountPerGeneBonferroni["Ensembl Gene ID"] = eQTLCountPerGeneBonferroni["Ensembl Gene ID"].apply(removeGeneIDVersions)
    
    merge1 = pd.merge(genesWitheQTLTissueCountBonferroniAndHaploStatus[['Ensembl Gene ID','haplo']], numTestedSNPs, how = "inner", on = "Ensembl Gene ID")
    merge2 = pd.merge(merge1, eQTLCountPerGeneBonferroni, how = "left", on = "Ensembl Gene ID")
    merge2['eQTLs'] = merge2['eQTLs'].fillna(0)
    
    merge2['propSignif'] = merge2['eQTLs']/merge2['SNPs']
    merge2['tissue'] = tissue
    allTissuesCombined_Haplo_bonferroni = allTissuesCombined_Haplo_bonferroni.append(merge2)
# Out:
# Adipose - Subcutaneous
# Adipose - Visceral (Omentum)
# Adrenal Gland
# Artery - Aorta
# Artery - Coronary
# Artery - Tibial
# Brain - Amygdala
# Brain - Anterior cingulate cortex (BA24)
# Brain - Caudate (basal ganglia)
# Brain - Cerebellar Hemisphere
# Brain - Cerebellum
# Brain - Cortex
# Brain - Frontal Cortex (BA9)
# Brain - Hippocampus
# Brain - Hypothalamus
# Brain - Nucleus accumbens (basal ganglia)
# Brain - Putamen (basal ganglia)
# Brain - Spinal cord (cervical c-1)
# Brain - Substantia nigra
# Breast - Mammary Tissue
# Cells - EBV-transformed lymphocytes
# Cells - Transformed fibroblasts
# Colon - Sigmoid
# Colon - Transverse
# Esophagus - Gastroesophageal Junction
# Esophagus - Mucosa
# Esophagus - Muscularis
# Heart - Atrial Appendage
# Heart - Left Ventricle
# Liver
# Lung
# Minor Salivary Gland
# Muscle - Skeletal
# Nerve - Tibial
# Ovary
# Pancreas
# Pituitary
# Prostate
# Skin - Not Sun Exposed (Suprapubic)
# Skin - Sun Exposed (Lower leg)
# Small Intestine - Terminal Ileum
# Spleen
# Stomach
# Testis
# Thyroid
# Uterus
# Vagina
# Whole Blood

# %%
allTissuesCombined_Haplo_bonferroni
# Out:
#        Ensembl Gene ID haplo    field   SNPs  eQTLs  propSignif  \
# 0      ENSG00000138593     N  gene_id   5645    0.0    0.000000
# 1      ENSG00000168675     N  gene_id   7911    0.0    0.000000
# 2      ENSG00000188992     N  gene_id   8607    0.0    0.000000
# 3      ENSG00000185272     N  gene_id   8622    0.0    0.000000
# 4      ENSG00000155304     N  gene_id   8566    0.0    0.000000
# 5      ENSG00000153575     N  gene_id   4601   89.0    0.019344
# 6      ENSG00000180530     Y  gene_id   8460    0.0    0.000000
# 7      ENSG00000137824     N  gene_id   5804   25.0    0.004307
# 8      ENSG00000137880     N  gene_id   5790    0.0    0.000000
# 9      ENSG00000104129     N  gene_id   5741    1.0    0.000174
# 10     ENSG00000177150     N  gene_id   8431    0.0    0.000000
# 11     ENSG00000155313     Y  gene_id   7272    0.0    0.000000
# 12     ENSG00000101638     N  gene_id   7134    0.0    0.000000
# 13     ENSG00000154639     N  gene_id   8762    0.0    0.000000
# 14     ENSG00000101654     N  gene_id   8431    0.0    0.000000
# 15     ENSG00000078043     Y  gene_id   7044   15.0    0.002129
# 16     ENSG00000156958     N  gene_id   5891    0.0    0.000000
# 17     ENSG00000154640     N  gene_id   8876    0.0    0.000000
# 18     ENSG00000140416     N  gene_id   7646   79.0    0.010332
# 19     ENSG00000154642     N  gene_id   9175    0.0    0.000000
# 20     ENSG00000140577     Y  gene_id   8399    2.0    0.000238
# 21     ENSG00000166140     N  gene_id   5723  433.0    0.075660
# 22     ENSG00000101138     Y  gene_id   8863    4.0    0.000451
# 23     ENSG00000154645     N  gene_id   9301    0.0    0.000000
# 24     ENSG00000068793     Y  gene_id   4852   34.0    0.007007
# 25     ENSG00000182931     N  gene_id   6706    0.0    0.000000
# 26     ENSG00000101365     N  gene_id   8212    0.0    0.000000
# 27     ENSG00000167216     N  gene_id   7041  323.0    0.045874
# 28     ENSG00000124116     N  gene_id   6832  671.0    0.098214
# 29     ENSG00000087589     N  gene_id   8902    0.0    0.000000
# ...                ...   ...      ...    ...    ...         ...
# 13727  ENSG00000175520     N  gene_id  11627    0.0    0.000000
# 13728  ENSG00000124196     N  gene_id   6778    0.0    0.000000
# 13729  ENSG00000182611     N  gene_id   6993    0.0    0.000000
# 13730  ENSG00000124529     N  gene_id   7949    0.0    0.000000
# 13731  ENSG00000171136     N  gene_id   7873    0.0    0.000000
# 13732  ENSG00000175514     N  gene_id   6045    0.0    0.000000
# 13733  ENSG00000167360     N  gene_id  11871    0.0    0.000000
# 13734  ENSG00000124693     N  gene_id   7945    0.0    0.000000
# 13735  ENSG00000105507     N  gene_id   8218    0.0    0.000000
# 13736  ENSG00000181616     N  gene_id  11284    0.0    0.000000
# 13737  ENSG00000182393     N  gene_id   7281    0.0    0.000000
# 13738  ENSG00000175779     N  gene_id   7972    0.0    0.000000
# 13739  ENSG00000175485     N  gene_id  10350    0.0    0.000000
# 13740  ENSG00000156575     N  gene_id   7207    0.0    0.000000
# 13741  ENSG00000221937     N  gene_id   5344    0.0    0.000000
# 13742  ENSG00000105370     N  gene_id   9585    0.0    0.000000
# 13743  ENSG00000182572     N  gene_id   7191    0.0    0.000000
# 13744  ENSG00000176895     N  gene_id  12141    0.0    0.000000
# 13745  ENSG00000187918     N  gene_id  11780    0.0    0.000000
# 13746  ENSG00000176922     N  gene_id  11980    0.0    0.000000
# 13747  ENSG00000167359     N  gene_id  11815    0.0    0.000000
# 13748  ENSG00000184881     N  gene_id  12070    0.0    0.000000
# 13749  ENSG00000255307     N  gene_id  10601    0.0    0.000000
# 13750  ENSG00000171987     N  gene_id  11519    0.0    0.000000
# 13751  ENSG00000221996     N  gene_id  11514    0.0    0.000000
# 13752  ENSG00000197790     N  gene_id  11539    0.0    0.000000
# 13753  ENSG00000184698     N  gene_id  12039    0.0    0.000000
# 13754  ENSG00000176239     N  gene_id  12059    0.0    0.000000
# 13755  ENSG00000182070     N  gene_id  12441    0.0    0.000000
# 13756  ENSG00000176893     N  gene_id  12167    0.0    0.000000
#
#                        tissue
# 0      Adipose - Subcutaneous
# 1      Adipose - Subcutaneous
# 2      Adipose - Subcutaneous
# 3      Adipose - Subcutaneous
# 4      Adipose - Subcutaneous
# 5      Adipose - Subcutaneous
# 6      Adipose - Subcutaneous
# 7      Adipose - Subcutaneous
# 8      Adipose - Subcutaneous
# 9      Adipose - Subcutaneous
# 10     Adipose - Subcutaneous
# 11     Adipose - Subcutaneous
# 12     Adipose - Subcutaneous
# 13     Adipose - Subcutaneous
# 14     Adipose - Subcutaneous
# 15     Adipose - Subcutaneous
# 16     Adipose - Subcutaneous
# 17     Adipose - Subcutaneous
# 18     Adipose - Subcutaneous
# 19     Adipose - Subcutaneous
# 20     Adipose - Subcutaneous
# 21     Adipose - Subcutaneous
# 22     Adipose - Subcutaneous
# 23     Adipose - Subcutaneous
# 24     Adipose - Subcutaneous
# 25     Adipose - Subcutaneous
# 26     Adipose - Subcutaneous
# 27     Adipose - Subcutaneous
# 28     Adipose - Subcutaneous
# 29     Adipose - Subcutaneous
# ...                       ...
# 13727             Whole Blood
# 13728             Whole Blood
# 13729             Whole Blood
# 13730             Whole Blood
# 13731             Whole Blood
# 13732             Whole Blood
# 13733             Whole Blood
# 13734             Whole Blood
# 13735             Whole Blood
# 13736             Whole Blood
# 13737             Whole Blood
# 13738             Whole Blood
# 13739             Whole Blood
# 13740             Whole Blood
# 13741             Whole Blood
# 13742             Whole Blood
# 13743             Whole Blood
# 13744             Whole Blood
# 13745             Whole Blood
# 13746             Whole Blood
# 13747             Whole Blood
# 13748             Whole Blood
# 13749             Whole Blood
# 13750             Whole Blood
# 13751             Whole Blood
# 13752             Whole Blood
# 13753             Whole Blood
# 13754             Whole Blood
# 13755             Whole Blood
# 13756             Whole Blood
#
# [724409 rows x 7 columns]

# %%
allTissuesCombined_Haplo_bonferroni.describe()
# Out:
#                 SNPs          eQTLs     propSignif
# count  724409.000000  724409.000000  724409.000000
# mean     7334.491661      17.525046       0.002490
# std      2132.637488      86.479499       0.011607
# min       119.000000       0.000000       0.000000
# 25%      6256.000000       0.000000       0.000000
# 50%      7228.000000       0.000000       0.000000
# 75%      8149.000000       0.000000       0.000000
# max     28260.000000    4540.000000       0.524256

# %%
allTissuesCombined_Haplo_bonferroni.to_csv('../../outputFiles/propSNPsSignificanteQTLsHaploBonferroni.csv', index=False)

# %% [markdown]
# ##### Metasoft eQTLs

# %%
allTissuesCombined_Haplo_metasoft = pd.DataFrame()
for tissue in tissues:
    print(tissue)
    tissue_url = tissue.replace(' - ','_').replace('(','').replace(')','').replace(' ','_')
    eQTLCountPerGeneMetasoft = pd.read_sql_query(
        'SELECT gene as "Ensembl Gene ID", COUNT(*) as eQTLs FROM `v7Metasoft` WHERE `mval_' + tissue_url + '` > 0.9 GROUP BY gene',
        engine,
        coerce_float=True
    )
    numTestedSNPs = pd.read_csv('../../outputFiles/GTExV7/numTestedSNPs/' + tissue + '.txt')
    numTestedSNPs.rename(columns={'value': 'Ensembl Gene ID', 'count': 'SNPs'}, inplace=True)
    genesWitheQTLTissueCountMetasoftAndHaploStatus = pd.read_csv('../../outputFiles/genesWitheQTLTissueCountMetasoftAndHaploStatus.csv', sep="\t", index_col="Unnamed: 0")
    
    numTestedSNPs["Ensembl Gene ID"] = numTestedSNPs["Ensembl Gene ID"].apply(removeGeneIDVersions)
    eQTLCountPerGeneMetasoft["Ensembl Gene ID"] = eQTLCountPerGeneMetasoft["Ensembl Gene ID"].apply(removeGeneIDVersions)
    
    merge1 = pd.merge(genesWitheQTLTissueCountMetasoftAndHaploStatus[['Ensembl Gene ID','haplo']], numTestedSNPs, how = "inner", on = "Ensembl Gene ID")
    merge2 = pd.merge(merge1, eQTLCountPerGeneMetasoft, how = "left", on = "Ensembl Gene ID")
    merge2['eQTLs'] = merge2['eQTLs'].fillna(0)
    
    merge2['propSignif'] = merge2['eQTLs']/merge2['SNPs']
    merge2['tissue'] = tissue
    allTissuesCombined_Haplo_metasoft = allTissuesCombined_Haplo_metasoft.append(merge2)
# Out:
# Adipose - Subcutaneous
# Adipose - Visceral (Omentum)
# Adrenal Gland
# Artery - Aorta
# Artery - Coronary
# Artery - Tibial
# Brain - Amygdala
# Brain - Anterior cingulate cortex (BA24)
# Brain - Caudate (basal ganglia)
# Brain - Cerebellar Hemisphere
# Brain - Cerebellum
# Brain - Cortex
# Brain - Frontal Cortex (BA9)
# Brain - Hippocampus
# Brain - Hypothalamus
# Brain - Nucleus accumbens (basal ganglia)
# Brain - Putamen (basal ganglia)
# Brain - Spinal cord (cervical c-1)
# Brain - Substantia nigra
# Breast - Mammary Tissue
# Cells - EBV-transformed lymphocytes
# Cells - Transformed fibroblasts
# Colon - Sigmoid
# Colon - Transverse
# Esophagus - Gastroesophageal Junction
# Esophagus - Mucosa
# Esophagus - Muscularis
# Heart - Atrial Appendage
# Heart - Left Ventricle
# Liver
# Lung
# Minor Salivary Gland
# Muscle - Skeletal
# Nerve - Tibial
# Ovary
# Pancreas
# Pituitary
# Prostate
# Skin - Not Sun Exposed (Suprapubic)
# Skin - Sun Exposed (Lower leg)
# Small Intestine - Terminal Ileum
# Spleen
# Stomach
# Testis
# Thyroid
# Uterus
# Vagina
# Whole Blood

# %%
allTissuesCombined_Haplo_metasoft
# Out:
#        Ensembl Gene ID haplo    field   SNPs  eQTLs  propSignif  \
# 0      ENSG00000138593     N  gene_id   5645   16.0    0.002834
# 1      ENSG00000168675     N  gene_id   7911    0.0    0.000000
# 2      ENSG00000188992     N  gene_id   8607  248.0    0.028814
# 3      ENSG00000185272     N  gene_id   8622  111.0    0.012874
# 4      ENSG00000155304     N  gene_id   8566   26.0    0.003035
# 5      ENSG00000166200     Y  gene_id   5891   30.0    0.005093
# 6      ENSG00000155307     N  gene_id   8545    0.0    0.000000
# 7      ENSG00000153575     N  gene_id   4601  130.0    0.028255
# 8      ENSG00000180530     Y  gene_id   8460    0.0    0.000000
# 9      ENSG00000137824     N  gene_id   5804  141.0    0.024294
# 10     ENSG00000137880     N  gene_id   5790    0.0    0.000000
# 11     ENSG00000104129     N  gene_id   5741  295.0    0.051385
# 12     ENSG00000177150     N  gene_id   8431   98.0    0.011624
# 13     ENSG00000155313     Y  gene_id   7272    3.0    0.000413
# 14     ENSG00000101638     N  gene_id   7134  145.0    0.020325
# 15     ENSG00000154639     N  gene_id   8762    1.0    0.000114
# 16     ENSG00000101654     N  gene_id   8431   67.0    0.007947
# 17     ENSG00000078043     Y  gene_id   7044  334.0    0.047416
# 18     ENSG00000156958     N  gene_id   5891   10.0    0.001698
# 19     ENSG00000154640     N  gene_id   8876    4.0    0.000451
# 20     ENSG00000140416     N  gene_id   7646  198.0    0.025896
# 21     ENSG00000154642     N  gene_id   9175    0.0    0.000000
# 22     ENSG00000140577     Y  gene_id   8399  100.0    0.011906
# 23     ENSG00000166140     N  gene_id   5723  727.0    0.127031
# 24     ENSG00000101138     Y  gene_id   8863   90.0    0.010155
# 25     ENSG00000154645     N  gene_id   9301   25.0    0.002688
# 26     ENSG00000068793     Y  gene_id   4852  107.0    0.022053
# 27     ENSG00000182931     N  gene_id   6706   14.0    0.002088
# 28     ENSG00000101365     N  gene_id   8212   95.0    0.011568
# 29     ENSG00000167216     N  gene_id   7041  457.0    0.064906
# ...                ...   ...      ...    ...    ...         ...
# 13727  ENSG00000107447     N  gene_id   6846    0.0    0.000000
# 13728  ENSG00000132703     N  gene_id   8050    0.0    0.000000
# 13729  ENSG00000101323     N  gene_id   8213    0.0    0.000000
# 13730  ENSG00000196532     N  gene_id   7915    0.0    0.000000
# 13731  ENSG00000175520     N  gene_id  11627    0.0    0.000000
# 13732  ENSG00000124196     N  gene_id   6778    0.0    0.000000
# 13733  ENSG00000124529     N  gene_id   7949    0.0    0.000000
# 13734  ENSG00000171136     N  gene_id   7873    0.0    0.000000
# 13735  ENSG00000175514     N  gene_id   6045    0.0    0.000000
# 13736  ENSG00000124693     N  gene_id   7945    0.0    0.000000
# 13737  ENSG00000105507     N  gene_id   8218    0.0    0.000000
# 13738  ENSG00000181616     N  gene_id  11284    0.0    0.000000
# 13739  ENSG00000182393     N  gene_id   7281    0.0    0.000000
# 13740  ENSG00000175779     N  gene_id   7972    0.0    0.000000
# 13741  ENSG00000175485     N  gene_id  10350    0.0    0.000000
# 13742  ENSG00000156575     N  gene_id   7207    0.0    0.000000
# 13743  ENSG00000221937     N  gene_id   5344    0.0    0.000000
# 13744  ENSG00000105370     N  gene_id   9585    0.0    0.000000
# 13745  ENSG00000182572     N  gene_id   7191    0.0    0.000000
# 13746  ENSG00000176922     N  gene_id  11980    0.0    0.000000
# 13747  ENSG00000167359     N  gene_id  11815    0.0    0.000000
# 13748  ENSG00000184881     N  gene_id  12070    0.0    0.000000
# 13749  ENSG00000255307     N  gene_id  10601    0.0    0.000000
# 13750  ENSG00000171987     N  gene_id  11519    0.0    0.000000
# 13751  ENSG00000221996     N  gene_id  11514    0.0    0.000000
# 13752  ENSG00000197790     N  gene_id  11539    0.0    0.000000
# 13753  ENSG00000184698     N  gene_id  12039    0.0    0.000000
# 13754  ENSG00000176239     N  gene_id  12059    0.0    0.000000
# 13755  ENSG00000182070     N  gene_id  12441    0.0    0.000000
# 13756  ENSG00000176893     N  gene_id  12167    0.0    0.000000
#
#                        tissue
# 0      Adipose - Subcutaneous
# 1      Adipose - Subcutaneous
# 2      Adipose - Subcutaneous
# 3      Adipose - Subcutaneous
# 4      Adipose - Subcutaneous
# 5      Adipose - Subcutaneous
# 6      Adipose - Subcutaneous
# 7      Adipose - Subcutaneous
# 8      Adipose - Subcutaneous
# 9      Adipose - Subcutaneous
# 10     Adipose - Subcutaneous
# 11     Adipose - Subcutaneous
# 12     Adipose - Subcutaneous
# 13     Adipose - Subcutaneous
# 14     Adipose - Subcutaneous
# 15     Adipose - Subcutaneous
# 16     Adipose - Subcutaneous
# 17     Adipose - Subcutaneous
# 18     Adipose - Subcutaneous
# 19     Adipose - Subcutaneous
# 20     Adipose - Subcutaneous
# 21     Adipose - Subcutaneous
# 22     Adipose - Subcutaneous
# 23     Adipose - Subcutaneous
# 24     Adipose - Subcutaneous
# 25     Adipose - Subcutaneous
# 26     Adipose - Subcutaneous
# 27     Adipose - Subcutaneous
# 28     Adipose - Subcutaneous
# 29     Adipose - Subcutaneous
# ...                       ...
# 13727             Whole Blood
# 13728             Whole Blood
# 13729             Whole Blood
# 13730             Whole Blood
# 13731             Whole Blood
# 13732             Whole Blood
# 13733             Whole Blood
# 13734             Whole Blood
# 13735             Whole Blood
# 13736             Whole Blood
# 13737             Whole Blood
# 13738             Whole Blood
# 13739             Whole Blood
# 13740             Whole Blood
# 13741             Whole Blood
# 13742             Whole Blood
# 13743             Whole Blood
# 13744             Whole Blood
# 13745             Whole Blood
# 13746             Whole Blood
# 13747             Whole Blood
# 13748             Whole Blood
# 13749             Whole Blood
# 13750             Whole Blood
# 13751             Whole Blood
# 13752             Whole Blood
# 13753             Whole Blood
# 13754             Whole Blood
# 13755             Whole Blood
# 13756             Whole Blood
#
# [724409 rows x 7 columns]

# %%
allTissuesCombined_Haplo_metasoft.describe()
# Out:
#                 SNPs          eQTLs     propSignif
# count  724409.000000  724409.000000  724409.000000
# mean     7334.491661     103.041729       0.014600
# std      2132.637488     262.663843       0.032225
# min       119.000000       0.000000       0.000000
# 25%      6256.000000       0.000000       0.000000
# 50%      7228.000000      14.000000       0.001882
# 75%      8149.000000     109.000000       0.015187
# max     28260.000000    8955.000000       0.653515

# %%
allTissuesCombined_Haplo_metasoft.to_csv('../../outputFiles/propSNPsSignificanteQTLsHaploMetasoft.csv', index=False)

# %% [markdown]
# #### Conserved copy number genes

# %% [markdown]
# ##### Bonferroni-corrected eQTLs

# %%
allTissuesCombined_CCN_bonferroni = pd.DataFrame()
for tissue in tissues:
    print(tissue)
    tissue_url = tissue.replace(' - ','_').replace('(','').replace(')','').replace(' ','_')
    eQTLCountPerGeneBonferroni = pd.read_sql_query(
        'SELECT gene_id as "Ensembl Gene ID", COUNT(*) as eQTLs FROM `v7` WHERE sigAfterBonferroni = 1 AND tissue = "' + tissue + '" GROUP BY gene_id',
        engine,
        coerce_float=True
    )
    numTestedSNPs = pd.read_csv('../../outputFiles/GTExV7/numTestedSNPs/' + tissue + '.txt')
    numTestedSNPs.rename(columns={'value': 'Ensembl Gene ID', 'count': 'SNPs'}, inplace=True)
    genesWitheQTLTissueCountBonferroniAndCCNStatus = pd.read_csv('../../outputFiles/genesWitheQTLTissueCountBonferroniAndCCNStatus.csv', sep="\t", index_col="Unnamed: 0")
    
    numTestedSNPs["Ensembl Gene ID"] = numTestedSNPs["Ensembl Gene ID"].apply(removeGeneIDVersions)
    eQTLCountPerGeneBonferroni["Ensembl Gene ID"] = eQTLCountPerGeneBonferroni["Ensembl Gene ID"].apply(removeGeneIDVersions)
    
    merge1 = pd.merge(genesWitheQTLTissueCountBonferroniAndCCNStatus[['Ensembl Gene ID','CCN']], numTestedSNPs, how = "inner", on = "Ensembl Gene ID")
    merge2 = pd.merge(merge1, eQTLCountPerGeneBonferroni, how = "left", on = "Ensembl Gene ID")
    merge2['eQTLs'] = merge2['eQTLs'].fillna(0)
    
    merge2['propSignif'] = merge2['eQTLs']/merge2['SNPs']
    merge2['tissue'] = tissue
    allTissuesCombined_CCN_bonferroni = allTissuesCombined_CCN_bonferroni.append(merge2)
# Out:
# Adipose - Subcutaneous
# Adipose - Visceral (Omentum)
# Adrenal Gland
# Artery - Aorta
# Artery - Coronary
# Artery - Tibial
# Brain - Amygdala
# Brain - Anterior cingulate cortex (BA24)
# Brain - Caudate (basal ganglia)
# Brain - Cerebellar Hemisphere
# Brain - Cerebellum
# Brain - Cortex
# Brain - Frontal Cortex (BA9)
# Brain - Hippocampus
# Brain - Hypothalamus
# Brain - Nucleus accumbens (basal ganglia)
# Brain - Putamen (basal ganglia)
# Brain - Spinal cord (cervical c-1)
# Brain - Substantia nigra
# Breast - Mammary Tissue
# Cells - EBV-transformed lymphocytes
# Cells - Transformed fibroblasts
# Colon - Sigmoid
# Colon - Transverse
# Esophagus - Gastroesophageal Junction
# Esophagus - Mucosa
# Esophagus - Muscularis
# Heart - Atrial Appendage
# Heart - Left Ventricle
# Liver
# Lung
# Minor Salivary Gland
# Muscle - Skeletal
# Nerve - Tibial
# Ovary
# Pancreas
# Pituitary
# Prostate
# Skin - Not Sun Exposed (Suprapubic)
# Skin - Sun Exposed (Lower leg)
# Small Intestine - Terminal Ileum
# Spleen
# Stomach
# Testis
# Thyroid
# Uterus
# Vagina
# Whole Blood

# %%
allTissuesCombined_CCN_bonferroni
# Out:
#        Ensembl Gene ID CCN    field   SNPs  eQTLs  propSignif  \
# 0      ENSG00000138593   Y  gene_id   5645    0.0    0.000000
# 1      ENSG00000168675   Y  gene_id   7911    0.0    0.000000
# 2      ENSG00000188992   N  gene_id   8607    0.0    0.000000
# 3      ENSG00000185272   N  gene_id   8622    0.0    0.000000
# 4      ENSG00000155304   Y  gene_id   8566    0.0    0.000000
# 5      ENSG00000153575   Y  gene_id   4601   89.0    0.019344
# 6      ENSG00000180530   Y  gene_id   8460    0.0    0.000000
# 7      ENSG00000137824   N  gene_id   5804   25.0    0.004307
# 8      ENSG00000137880   Y  gene_id   5790    0.0    0.000000
# 9      ENSG00000104129   N  gene_id   5741    1.0    0.000174
# 10     ENSG00000177150   N  gene_id   8431    0.0    0.000000
# 11     ENSG00000155313   N  gene_id   7272    0.0    0.000000
# 12     ENSG00000101638   Y  gene_id   7134    0.0    0.000000
# 13     ENSG00000154639   N  gene_id   8762    0.0    0.000000
# 14     ENSG00000101654   N  gene_id   8431    0.0    0.000000
# 15     ENSG00000078043   Y  gene_id   7044   15.0    0.002129
# 16     ENSG00000156958   Y  gene_id   5891    0.0    0.000000
# 17     ENSG00000154640   N  gene_id   8876    0.0    0.000000
# 18     ENSG00000140416   N  gene_id   7646   79.0    0.010332
# 19     ENSG00000154642   Y  gene_id   9175    0.0    0.000000
# 20     ENSG00000140577   N  gene_id   8399    2.0    0.000238
# 21     ENSG00000166140   N  gene_id   5723  433.0    0.075660
# 22     ENSG00000101138   Y  gene_id   8863    4.0    0.000451
# 23     ENSG00000154645   Y  gene_id   9301    0.0    0.000000
# 24     ENSG00000068793   Y  gene_id   4852   34.0    0.007007
# 25     ENSG00000182931   N  gene_id   6706    0.0    0.000000
# 26     ENSG00000101365   N  gene_id   8212    0.0    0.000000
# 27     ENSG00000167216   Y  gene_id   7041  323.0    0.045874
# 28     ENSG00000124116   N  gene_id   6832  671.0    0.098214
# 29     ENSG00000087589   Y  gene_id   8902    0.0    0.000000
# ...                ...  ..      ...    ...    ...         ...
# 14558  ENSG00000167360   N  gene_id  11871    0.0    0.000000
# 14559  ENSG00000124693   N  gene_id   7945    0.0    0.000000
# 14560  ENSG00000105507   Y  gene_id   8218    0.0    0.000000
# 14561  ENSG00000187475   N  gene_id   7753    0.0    0.000000
# 14562  ENSG00000181616   N  gene_id  11284    0.0    0.000000
# 14563  ENSG00000185990   N  gene_id   2336    0.0    0.000000
# 14564  ENSG00000182393   N  gene_id   7281    0.0    0.000000
# 14565  ENSG00000175779   N  gene_id   7972    0.0    0.000000
# 14566  ENSG00000175485   N  gene_id  10350    0.0    0.000000
# 14567  ENSG00000184321   N  gene_id  11982    0.0    0.000000
# 14568  ENSG00000156575   N  gene_id   7207    0.0    0.000000
# 14569  ENSG00000221937   N  gene_id   5344    0.0    0.000000
# 14570  ENSG00000105370   Y  gene_id   9585    0.0    0.000000
# 14571  ENSG00000182572   N  gene_id   7191    0.0    0.000000
# 14572  ENSG00000176895   N  gene_id  12141    0.0    0.000000
# 14573  ENSG00000240247   N  gene_id   9793    0.0    0.000000
# 14574  ENSG00000187918   N  gene_id  11780    0.0    0.000000
# 14575  ENSG00000176922   N  gene_id  11980    0.0    0.000000
# 14576  ENSG00000167359   N  gene_id  11815    0.0    0.000000
# 14577  ENSG00000184881   N  gene_id  12070    0.0    0.000000
# 14578  ENSG00000255307   N  gene_id  10601    0.0    0.000000
# 14579  ENSG00000171987   N  gene_id  11519    0.0    0.000000
# 14580  ENSG00000205300   N  gene_id   8719    0.0    0.000000
# 14581  ENSG00000221996   N  gene_id  11514    0.0    0.000000
# 14582  ENSG00000197790   N  gene_id  11539    0.0    0.000000
# 14583  ENSG00000184698   N  gene_id  12039    0.0    0.000000
# 14584  ENSG00000206047   N  gene_id  10043    0.0    0.000000
# 14585  ENSG00000176239   N  gene_id  12059    0.0    0.000000
# 14586  ENSG00000182070   N  gene_id  12441    0.0    0.000000
# 14587  ENSG00000176893   N  gene_id  12167    0.0    0.000000
#
#                        tissue
# 0      Adipose - Subcutaneous
# 1      Adipose - Subcutaneous
# 2      Adipose - Subcutaneous
# 3      Adipose - Subcutaneous
# 4      Adipose - Subcutaneous
# 5      Adipose - Subcutaneous
# 6      Adipose - Subcutaneous
# 7      Adipose - Subcutaneous
# 8      Adipose - Subcutaneous
# 9      Adipose - Subcutaneous
# 10     Adipose - Subcutaneous
# 11     Adipose - Subcutaneous
# 12     Adipose - Subcutaneous
# 13     Adipose - Subcutaneous
# 14     Adipose - Subcutaneous
# 15     Adipose - Subcutaneous
# 16     Adipose - Subcutaneous
# 17     Adipose - Subcutaneous
# 18     Adipose - Subcutaneous
# 19     Adipose - Subcutaneous
# 20     Adipose - Subcutaneous
# 21     Adipose - Subcutaneous
# 22     Adipose - Subcutaneous
# 23     Adipose - Subcutaneous
# 24     Adipose - Subcutaneous
# 25     Adipose - Subcutaneous
# 26     Adipose - Subcutaneous
# 27     Adipose - Subcutaneous
# 28     Adipose - Subcutaneous
# 29     Adipose - Subcutaneous
# ...                       ...
# 14558             Whole Blood
# 14559             Whole Blood
# 14560             Whole Blood
# 14561             Whole Blood
# 14562             Whole Blood
# 14563             Whole Blood
# 14564             Whole Blood
# 14565             Whole Blood
# 14566             Whole Blood
# 14567             Whole Blood
# 14568             Whole Blood
# 14569             Whole Blood
# 14570             Whole Blood
# 14571             Whole Blood
# 14572             Whole Blood
# 14573             Whole Blood
# 14574             Whole Blood
# 14575             Whole Blood
# 14576             Whole Blood
# 14577             Whole Blood
# 14578             Whole Blood
# 14579             Whole Blood
# 14580             Whole Blood
# 14581             Whole Blood
# 14582             Whole Blood
# 14583             Whole Blood
# 14584             Whole Blood
# 14585             Whole Blood
# 14586             Whole Blood
# 14587             Whole Blood
#
# [774180 rows x 7 columns]

# %%
allTissuesCombined_CCN_bonferroni.describe()
# Out:
#                 SNPs          eQTLs     propSignif
# count  774180.000000  774180.000000  774180.000000
# mean     7198.019774      17.562916       0.002570
# std      2234.033048      90.408335       0.012775
# min       119.000000       0.000000       0.000000
# 25%      6107.000000       0.000000       0.000000
# 50%      7156.000000       0.000000       0.000000
# 75%      8118.000000       0.000000       0.000000
# max     28260.000000    4540.000000       0.524256

# %%
allTissuesCombined_CCN_bonferroni.to_csv('../../outputFiles/propSNPsSignificanteQTLsCCNBonferroni.csv', index=False)

# %% [markdown]
# ##### Metasoft eQTLs

# %%
allTissuesCombined_CCN_metasoft = pd.DataFrame()
for tissue in tissues:
    print(tissue)
    tissue_url = tissue.replace(' - ','_').replace('(','').replace(')','').replace(' ','_')
    eQTLCountPerGeneMetasoft = pd.read_sql_query(
        'SELECT gene as "Ensembl Gene ID", COUNT(*) as eQTLs FROM `v7Metasoft` WHERE `mval_' + tissue_url + '` > 0.9 GROUP BY gene',
        engine,
        coerce_float=True
    )
    numTestedSNPs = pd.read_csv('../../outputFiles/GTExV7/numTestedSNPs/' + tissue + '.txt')
    numTestedSNPs.rename(columns={'value': 'Ensembl Gene ID', 'count': 'SNPs'}, inplace=True)
    genesWitheQTLTissueCountMetasoftAndCCNStatus = pd.read_csv('../../outputFiles/genesWitheQTLTissueCountMetasoftAndCCNStatus.csv', sep="\t", index_col="Unnamed: 0")
    
    numTestedSNPs["Ensembl Gene ID"] = numTestedSNPs["Ensembl Gene ID"].apply(removeGeneIDVersions)
    eQTLCountPerGeneMetasoft["Ensembl Gene ID"] = eQTLCountPerGeneMetasoft["Ensembl Gene ID"].apply(removeGeneIDVersions)
    
    merge1 = pd.merge(genesWitheQTLTissueCountMetasoftAndCCNStatus[['Ensembl Gene ID','CCN']], numTestedSNPs, how = "inner", on = "Ensembl Gene ID")
    merge2 = pd.merge(merge1, eQTLCountPerGeneMetasoft, how = "left", on = "Ensembl Gene ID")
    merge2['eQTLs'] = merge2['eQTLs'].fillna(0)
    
    merge2['propSignif'] = merge2['eQTLs']/merge2['SNPs']
    merge2['tissue'] = tissue
    allTissuesCombined_CCN_metasoft = allTissuesCombined_CCN_metasoft.append(merge2)
# Out:
# Adipose - Subcutaneous
# Adipose - Visceral (Omentum)
# Adrenal Gland
# Artery - Aorta
# Artery - Coronary
# Artery - Tibial
# Brain - Amygdala
# Brain - Anterior cingulate cortex (BA24)
# Brain - Caudate (basal ganglia)
# Brain - Cerebellar Hemisphere
# Brain - Cerebellum
# Brain - Cortex
# Brain - Frontal Cortex (BA9)
# Brain - Hippocampus
# Brain - Hypothalamus
# Brain - Nucleus accumbens (basal ganglia)
# Brain - Putamen (basal ganglia)
# Brain - Spinal cord (cervical c-1)
# Brain - Substantia nigra
# Breast - Mammary Tissue
# Cells - EBV-transformed lymphocytes
# Cells - Transformed fibroblasts
# Colon - Sigmoid
# Colon - Transverse
# Esophagus - Gastroesophageal Junction
# Esophagus - Mucosa
# Esophagus - Muscularis
# Heart - Atrial Appendage
# Heart - Left Ventricle
# Liver
# Lung
# Minor Salivary Gland
# Muscle - Skeletal
# Nerve - Tibial
# Ovary
# Pancreas
# Pituitary
# Prostate
# Skin - Not Sun Exposed (Suprapubic)
# Skin - Sun Exposed (Lower leg)
# Small Intestine - Terminal Ileum
# Spleen
# Stomach
# Testis
# Thyroid
# Uterus
# Vagina
# Whole Blood

# %%
allTissuesCombined_CCN_metasoft
# Out:
#        Ensembl Gene ID CCN    field   SNPs  eQTLs  propSignif  \
# 0      ENSG00000138593   Y  gene_id   5645   16.0    0.002834
# 1      ENSG00000168675   Y  gene_id   7911    0.0    0.000000
# 2      ENSG00000188992   N  gene_id   8607  248.0    0.028814
# 3      ENSG00000185272   N  gene_id   8622  111.0    0.012874
# 4      ENSG00000155304   Y  gene_id   8566   26.0    0.003035
# 5      ENSG00000166200   N  gene_id   5891   30.0    0.005093
# 6      ENSG00000155307   Y  gene_id   8545    0.0    0.000000
# 7      ENSG00000153575   Y  gene_id   4601  130.0    0.028255
# 8      ENSG00000180530   Y  gene_id   8460    0.0    0.000000
# 9      ENSG00000137824   N  gene_id   5804  141.0    0.024294
# 10     ENSG00000137880   Y  gene_id   5790    0.0    0.000000
# 11     ENSG00000104129   N  gene_id   5741  295.0    0.051385
# 12     ENSG00000177150   N  gene_id   8431   98.0    0.011624
# 13     ENSG00000155313   N  gene_id   7272    3.0    0.000413
# 14     ENSG00000101638   Y  gene_id   7134  145.0    0.020325
# 15     ENSG00000154639   N  gene_id   8762    1.0    0.000114
# 16     ENSG00000101654   N  gene_id   8431   67.0    0.007947
# 17     ENSG00000078043   Y  gene_id   7044  334.0    0.047416
# 18     ENSG00000156958   Y  gene_id   5891   10.0    0.001698
# 19     ENSG00000154640   N  gene_id   8876    4.0    0.000451
# 20     ENSG00000140416   N  gene_id   7646  198.0    0.025896
# 21     ENSG00000154642   Y  gene_id   9175    0.0    0.000000
# 22     ENSG00000140577   N  gene_id   8399  100.0    0.011906
# 23     ENSG00000166140   N  gene_id   5723  727.0    0.127031
# 24     ENSG00000101138   Y  gene_id   8863   90.0    0.010155
# 25     ENSG00000154645   Y  gene_id   9301   25.0    0.002688
# 26     ENSG00000068793   Y  gene_id   4852  107.0    0.022053
# 27     ENSG00000182931   N  gene_id   6706   14.0    0.002088
# 28     ENSG00000101365   N  gene_id   8212   95.0    0.011568
# 29     ENSG00000167216   Y  gene_id   7041  457.0    0.064906
# ...                ...  ..      ...    ...    ...         ...
# 14558  ENSG00000124529   N  gene_id   7949    0.0    0.000000
# 14559  ENSG00000171136   N  gene_id   7873    0.0    0.000000
# 14560  ENSG00000175514   N  gene_id   6045    0.0    0.000000
# 14561  ENSG00000124693   N  gene_id   7945    0.0    0.000000
# 14562  ENSG00000105507   Y  gene_id   8218    0.0    0.000000
# 14563  ENSG00000187475   N  gene_id   7753    0.0    0.000000
# 14564  ENSG00000181616   N  gene_id  11284    0.0    0.000000
# 14565  ENSG00000185990   N  gene_id   2336    0.0    0.000000
# 14566  ENSG00000182393   N  gene_id   7281    0.0    0.000000
# 14567  ENSG00000175779   N  gene_id   7972    0.0    0.000000
# 14568  ENSG00000175485   N  gene_id  10350    0.0    0.000000
# 14569  ENSG00000184321   N  gene_id  11982    0.0    0.000000
# 14570  ENSG00000156575   N  gene_id   7207    0.0    0.000000
# 14571  ENSG00000221937   N  gene_id   5344    0.0    0.000000
# 14572  ENSG00000105370   Y  gene_id   9585    0.0    0.000000
# 14573  ENSG00000182572   N  gene_id   7191    0.0    0.000000
# 14574  ENSG00000240247   N  gene_id   9793    0.0    0.000000
# 14575  ENSG00000176922   N  gene_id  11980    0.0    0.000000
# 14576  ENSG00000167359   N  gene_id  11815    0.0    0.000000
# 14577  ENSG00000184881   N  gene_id  12070    0.0    0.000000
# 14578  ENSG00000255307   N  gene_id  10601    0.0    0.000000
# 14579  ENSG00000171987   N  gene_id  11519    0.0    0.000000
# 14580  ENSG00000205300   N  gene_id   8719    0.0    0.000000
# 14581  ENSG00000221996   N  gene_id  11514    0.0    0.000000
# 14582  ENSG00000197790   N  gene_id  11539    0.0    0.000000
# 14583  ENSG00000184698   N  gene_id  12039    0.0    0.000000
# 14584  ENSG00000206047   N  gene_id  10043    0.0    0.000000
# 14585  ENSG00000176239   N  gene_id  12059    0.0    0.000000
# 14586  ENSG00000182070   N  gene_id  12441    0.0    0.000000
# 14587  ENSG00000176893   N  gene_id  12167    0.0    0.000000
#
#                        tissue
# 0      Adipose - Subcutaneous
# 1      Adipose - Subcutaneous
# 2      Adipose - Subcutaneous
# 3      Adipose - Subcutaneous
# 4      Adipose - Subcutaneous
# 5      Adipose - Subcutaneous
# 6      Adipose - Subcutaneous
# 7      Adipose - Subcutaneous
# 8      Adipose - Subcutaneous
# 9      Adipose - Subcutaneous
# 10     Adipose - Subcutaneous
# 11     Adipose - Subcutaneous
# 12     Adipose - Subcutaneous
# 13     Adipose - Subcutaneous
# 14     Adipose - Subcutaneous
# 15     Adipose - Subcutaneous
# 16     Adipose - Subcutaneous
# 17     Adipose - Subcutaneous
# 18     Adipose - Subcutaneous
# 19     Adipose - Subcutaneous
# 20     Adipose - Subcutaneous
# 21     Adipose - Subcutaneous
# 22     Adipose - Subcutaneous
# 23     Adipose - Subcutaneous
# 24     Adipose - Subcutaneous
# 25     Adipose - Subcutaneous
# 26     Adipose - Subcutaneous
# 27     Adipose - Subcutaneous
# 28     Adipose - Subcutaneous
# 29     Adipose - Subcutaneous
# ...                       ...
# 14558             Whole Blood
# 14559             Whole Blood
# 14560             Whole Blood
# 14561             Whole Blood
# 14562             Whole Blood
# 14563             Whole Blood
# 14564             Whole Blood
# 14565             Whole Blood
# 14566             Whole Blood
# 14567             Whole Blood
# 14568             Whole Blood
# 14569             Whole Blood
# 14570             Whole Blood
# 14571             Whole Blood
# 14572             Whole Blood
# 14573             Whole Blood
# 14574             Whole Blood
# 14575             Whole Blood
# 14576             Whole Blood
# 14577             Whole Blood
# 14578             Whole Blood
# 14579             Whole Blood
# 14580             Whole Blood
# 14581             Whole Blood
# 14582             Whole Blood
# 14583             Whole Blood
# 14584             Whole Blood
# 14585             Whole Blood
# 14586             Whole Blood
# 14587             Whole Blood
#
# [774180 rows x 7 columns]

# %%
allTissuesCombined_CCN_metasoft.describe()
# Out:
#                 SNPs          eQTLs     propSignif
# count  774180.000000  774180.000000  774180.000000
# mean     7198.019774     101.934655       0.014792
# std      2234.033048     265.261210       0.033449
# min       119.000000       0.000000       0.000000
# 25%      6107.000000       0.000000       0.000000
# 50%      7156.000000      13.000000       0.001800
# 75%      8118.000000     106.000000       0.015088
# max     28260.000000    8955.000000       0.653515

# %%
allTissuesCombined_CCN_metasoft.to_csv('../../outputFiles/propSNPsSignificanteQTLsCCNMetasoft.csv', index=False)
